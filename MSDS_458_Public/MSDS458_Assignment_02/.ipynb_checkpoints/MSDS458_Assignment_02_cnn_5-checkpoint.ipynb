# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/NorthwesternHeader.png?raw=1">

# %% [markdown]
# ## MSDS458 Research Assignment 02 - Part 1
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div><br>

# %% [markdown]
# The CIFAR-10 dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>The CIFAR-10 dataset</b><br>
# https://www.cs.toronto.edu/~kriz/cifar.html
#     </div>

# %% [markdown]
# ## Import packages needed

# %%
import datetime
import time
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ### Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.3.1

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.4.0

# %% [markdown]
# ### Mount Google Drive to Colab Environment

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ### Functions for Research Assignment

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ## Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.<br>
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# * Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
# * x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
# * y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)

# %% [markdown]
# ## EDA Training and Test Datasets
#
# * Imported 50000 examples for training and 10000 examples for test
# * Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t\t{}'.format(x_test.shape))
print('test_labels:\t\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# ### Review labels for training dataset

# %%
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# ### Plot Examples

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)
    
    x = x[indices]
    y = y[indices]
    
    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)
    
    x = x[indices]
    y = y[indices]
    
    y = tf.keras.utils.to_categorical(y)
    
    return x, y

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(train_images, train_labels)
x_preview, y_preview = get_three_classes(test_images, test_labels)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)
    
    x = x[indices]
    y = y[indices]
    p = p[indices]
    
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# ### Preprocessing Data for Model Development

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %% [markdown]
# ### Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# ### Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# ### Rescale Examples  {Train, Validation, Test}
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255

# %% [markdown]
# 1. Each element in each example is a pixel value
# 2. Pixel values range from 0 to 255
# 3. 0 = black
# 4. 255 = white

# %%
x_train_norm = x_train_split/255
x_valid_norm = x_valid_split/255
x_test_norm = x_test/255

# %% [markdown]
# ### RUN CELLS ABOVE

# %% [markdown]
# ## Create the Model

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/CNN_architecture_v4.png?raw=1">

# %% [markdown]
# ### Build CNN Model

# %% [markdown]
# We use a Sequential class defined in Keras to create our model. The first 9 layers Conv2D MaxPooling, Dropout handle feature learning.  The last 3 layers, handle classification

# %%
model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D((2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.L2(0.001)))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 256)       295168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 384)               786816
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                3850
# =================================================================
# Total params: 2,277,770
# Trainable params: 2,273,674
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "CIFAR10.png", show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %% [markdown]
# ### Compiling the model

# %% [markdown]
# In addition to setting up our model architecture, we also need to define which algorithm should the model use in order to optimize the weights and biases as per the given data. We will use stochastic gradient descent.
#
# We also need to define a loss function. Think of this function as the difference between the predicted outputs and the actual outputs given in the dataset. This loss needs to be minimised in order to have a higher model accuracy. That's what the optimization algorithm essentially does - it minimises the loss during model training. For our multi-class classification problem, categorical cross entropy is commonly used.
#
# Finally, we will use the accuracy during training as a metric to keep track of as the model trains.

# %% [markdown]
# ## Training the model

# %%
def compile_train_model(model, x_train, y_train, x_valid, y_valid, epochs=200):
  timestamp=int(time.time())
  
  # Compile
  model.compile(optimizer='rmsprop', # test adam
                loss = 'SparseCategoricalCrossentropy',
                metrics=['accuracy'])

  # Train
  start_time = time.time()
  history = model.fit(
    x_train,
    y_train,
    epochs=epochs,
    batch_size=512,
    validation_data=(x_valid, y_valid),
    #verbose=0,
    callbacks=[    
        EarlyStopping(monitor='val_accuracy', patience=3),
        ModelCheckpoint('./models/cnn/3/model_{val_accuracy:.4f}.h5',
                               save_best_only=True,
                               save_weights_only=False,
                               monitor='val_accuracy')]
  )
  end_time = time.time()
  second_elapsed = round(end_time - start_time)

  print(f'Finished model training in {second_elapsed}s')

  print('\nModel performance with training set')
  model.evaluate(x_train, y_train)

  print('\nEvaluating model performance with validation set')
  model.evaluate(x_valid, y_valid)

  return history, model

# %%
# Compile and train
history, model = compile_train_model(model,
                                     x_train_norm, y_train_split,
                                     x_valid_norm, y_valid_split
                                    )
# Out:
# Epoch 1/200
#  2/88 [..............................] - ETA: 21s - loss: 3.3332 - accuracy: 0.1250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1480s vs `on_train_batch_end` time: 0.3420s). Check your callbacks.
# 88/88 [==============================] - 46s 524ms/step - loss: 2.1640 - accuracy: 0.3860 - val_loss: 2.3902 - val_accuracy: 0.4506
# Epoch 2/200
# 88/88 [==============================] - 44s 494ms/step - loss: 1.4856 - accuracy: 0.5535 - val_loss: 2.1790 - val_accuracy: 0.4500
# Epoch 3/200
# 88/88 [==============================] - 76s 863ms/step - loss: 1.2379 - accuracy: 0.6262 - val_loss: 1.8371 - val_accuracy: 0.5622
# Epoch 4/200
# 88/88 [==============================] - 47s 533ms/step - loss: 1.0872 - accuracy: 0.6710 - val_loss: 1.4508 - val_accuracy: 0.6440
# Epoch 5/200
# 88/88 [==============================] - 44s 495ms/step - loss: 0.9787 - accuracy: 0.7038 - val_loss: 1.1360 - val_accuracy: 0.6790
# Epoch 6/200
# 88/88 [==============================] - 76s 863ms/step - loss: 0.9060 - accuracy: 0.7256 - val_loss: 0.9292 - val_accuracy: 0.7270
# Epoch 7/200
# 88/88 [==============================] - 76s 863ms/step - loss: 0.8372 - accuracy: 0.7483 - val_loss: 0.9769 - val_accuracy: 0.7018
# Epoch 8/200
# 88/88 [==============================] - 70s 798ms/step - loss: 0.7864 - accuracy: 0.7644 - val_loss: 1.0470 - val_accuracy: 0.6898
# Epoch 9/200
# 88/88 [==============================] - 48s 543ms/step - loss: 0.7383 - accuracy: 0.7818 - val_loss: 0.9297 - val_accuracy: 0.7274
# Epoch 10/200
# 88/88 [==============================] - 51s 576ms/step - loss: 0.7003 - accuracy: 0.7981 - val_loss: 0.7827 - val_accuracy: 0.7682
# Epoch 11/200
# 88/88 [==============================] - 44s 502ms/step - loss: 0.6687 - accuracy: 0.8052 - val_loss: 0.7794 - val_accuracy: 0.7718
# Epoch 12/200
# 88/88 [==============================] - 49s 553ms/step - loss: 0.6376 - accuracy: 0.8170 - val_loss: 0.7806 - val_accuracy: 0.7736
# Epoch 13/200
# 88/88 [==============================] - 45s 516ms/step - loss: 0.6108 - accuracy: 0.8270 - val_loss: 0.8192 - val_accuracy: 0.7724
# Epoch 14/200
# 88/88 [==============================] - 44s 495ms/step - loss: 0.5947 - accuracy: 0.8350 - val_loss: 0.8828 - val_accuracy: 0.7540
# Epoch 15/200
# 88/88 [==============================] - 63s 720ms/step - loss: 0.5688 - accuracy: 0.8426 - val_loss: 0.8139 - val_accuracy: 0.7766
# Epoch 16/200
# 88/88 [==============================] - 76s 864ms/step - loss: 0.5510 - accuracy: 0.8514 - val_loss: 0.8240 - val_accuracy: 0.7700
# Epoch 17/200
# 88/88 [==============================] - 76s 865ms/step - loss: 0.5373 - accuracy: 0.8562 - val_loss: 0.7941 - val_accuracy: 0.7764
# Epoch 18/200
# 88/88 [==============================] - 76s 864ms/step - loss: 0.5209 - accuracy: 0.8604 - val_loss: 0.7384 - val_accuracy: 0.8012
# Epoch 19/200
# 88/88 [==============================] - 76s 865ms/step - loss: 0.5065 - accuracy: 0.8680 - val_loss: 0.9218 - val_accuracy: 0.7594
# Epoch 20/200
# 88/88 [==============================] - 76s 864ms/step - loss: 0.4906 - accuracy: 0.8727 - val_loss: 0.8336 - val_accuracy: 0.7776
# Epoch 21/200
# 88/88 [==============================] - 76s 864ms/step - loss: 0.4874 - accuracy: 0.8740 - val_loss: 0.7913 - val_accuracy: 0.7822
# Finished model training in 1300s
#
# Model performance with training set
# 1407/1407 [==============================] - 26s 18ms/step - loss: 0.3217 - accuracy: 0.9470
#
# Evaluating model performance with validation set
# 157/157 [==============================] - 3s 18ms/step - loss: 0.7913 - accuracy: 0.7822

# %%
# # gdir: /content/gdrive/My Drive/Colab Notebooks/models

# history = model.fit(x_train_norm
#                     ,y_train_split
#                     ,epochs=200
#                     ,batch_size=512
#                     ,validation_data=(x_valid_norm, y_valid_split)
#                     ,callbacks=[
#                     tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
#                     tf.keras.callbacks.ModelCheckpoint('model_{val_accuracy:.4f}.h5', save_best_only=True,
#                                         save_weights_only=False, monitor='val_accuracy')]                                                                                                           
#                    )
# Out:
# Epoch 1/200
#  2/88 [..............................] - ETA: 36s - loss: 3.2659 - accuracy: 0.1201WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2454s vs `on_train_batch_end` time: 0.5952s). Check your callbacks.
# 88/88 [==============================] - 84s 957ms/step - loss: 2.2268 - accuracy: 0.3847 - val_loss: 2.5109 - val_accuracy: 0.4058
# Epoch 2/200
# 88/88 [==============================] - 75s 853ms/step - loss: 1.5481 - accuracy: 0.5687 - val_loss: 2.1823 - val_accuracy: 0.5352
# Epoch 3/200
# 88/88 [==============================] - 75s 855ms/step - loss: 1.2617 - accuracy: 0.6393 - val_loss: 1.8588 - val_accuracy: 0.6294
# Epoch 4/200
# 88/88 [==============================] - 75s 852ms/step - loss: 1.0865 - accuracy: 0.6813 - val_loss: 1.4982 - val_accuracy: 0.6914
# Epoch 5/200
# 88/88 [==============================] - 75s 851ms/step - loss: 0.9744 - accuracy: 0.7117 - val_loss: 1.2458 - val_accuracy: 0.6556
# Epoch 6/200
# 88/88 [==============================] - 76s 860ms/step - loss: 0.8841 - accuracy: 0.7365 - val_loss: 0.9305 - val_accuracy: 0.7390
# Epoch 7/200
# 88/88 [==============================] - 75s 854ms/step - loss: 0.8146 - accuracy: 0.7556 - val_loss: 0.8763 - val_accuracy: 0.7386
# Epoch 8/200
# 88/88 [==============================] - 75s 854ms/step - loss: 0.7707 - accuracy: 0.7695 - val_loss: 0.8365 - val_accuracy: 0.7452
# Epoch 9/200
# 88/88 [==============================] - 75s 853ms/step - loss: 0.7307 - accuracy: 0.7818 - val_loss: 0.7794 - val_accuracy: 0.7642
# Epoch 10/200
# 88/88 [==============================] - 75s 852ms/step - loss: 0.6976 - accuracy: 0.7949 - val_loss: 0.7943 - val_accuracy: 0.7582
# Epoch 11/200
# 88/88 [==============================] - 75s 852ms/step - loss: 0.6678 - accuracy: 0.8051 - val_loss: 0.7831 - val_accuracy: 0.7692
# Epoch 12/200
# 88/88 [==============================] - 75s 851ms/step - loss: 0.6408 - accuracy: 0.8158 - val_loss: 0.7625 - val_accuracy: 0.7692
# Epoch 13/200
# 88/88 [==============================] - 75s 852ms/step - loss: 0.6174 - accuracy: 0.8230 - val_loss: 0.7807 - val_accuracy: 0.7714
# Epoch 14/200
# 88/88 [==============================] - 75s 852ms/step - loss: 0.6044 - accuracy: 0.8298 - val_loss: 0.7264 - val_accuracy: 0.7882
# Epoch 15/200
# 88/88 [==============================] - 75s 852ms/step - loss: 0.5807 - accuracy: 0.8352 - val_loss: 0.7142 - val_accuracy: 0.7986
# Epoch 16/200
# 88/88 [==============================] - 75s 851ms/step - loss: 0.5716 - accuracy: 0.8402 - val_loss: 0.7491 - val_accuracy: 0.7900
# Epoch 17/200
# 88/88 [==============================] - 75s 851ms/step - loss: 0.5496 - accuracy: 0.8481 - val_loss: 0.7086 - val_accuracy: 0.7980
# Epoch 18/200
# 88/88 [==============================] - 75s 852ms/step - loss: 0.5390 - accuracy: 0.8518 - val_loss: 0.7690 - val_accuracy: 0.7850

# %% [markdown]
# ### Validation Data
# Data on which to evaluate the loss and any model metrics at the end of each epoch<br>
# The model will not be trained on this data

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# In order to ensure that this is not a simple "memorization" by the machine, we should evaluate the performance on the test set. This is easy to do, we simply use the `evaluate` method on our model.

# %%
loss, accuracy = model.evaluate(x_test_norm, y_test)
# Out:
# 313/313 [==============================] - 6s 18ms/step - loss: 0.8231 - accuracy: 0.7824
# test set accuracy:  78.24000120162964

# %% [markdown]
# ### No regularizer

# %%
model_n = models.Sequential()
model_n.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model_n.add(layers.MaxPool2D((2, 2),strides=2))
model_n.add(layers.Dropout(0.3))
model_n.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model_n.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model_n.add(layers.Dropout(0.3))
model_n.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model_n.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model_n.add(layers.Dropout(0.3))
model_n.add(layers.Flatten())
model_n.add(layers.BatchNormalization())
model_n.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=None))
model_n.add(layers.Dense(units=10, activation=tf.nn.softmax))

# Compile and train
history, model_n = compile_train_model(model_n,
                                     x_train_norm, y_train_split,
                                     x_valid_norm, y_valid_split
                                    )

print('\nEvaluating model performance with test set')
loss, accuracy = model_n.evaluate(x_test_norm, y_test)
# Out:
# Epoch 1/200
#  2/88 [..............................] - ETA: 20s - loss: 2.6753 - accuracy: 0.1104WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1440s vs `on_train_batch_end` time: 0.3420s). Check your callbacks.
# 88/88 [==============================] - 44s 501ms/step - loss: 1.6957 - accuracy: 0.3858 - val_loss: 2.1644 - val_accuracy: 0.2442
# Epoch 2/200
# 88/88 [==============================] - 43s 493ms/step - loss: 1.2488 - accuracy: 0.5549 - val_loss: 2.0033 - val_accuracy: 0.4818
# Epoch 3/200
# 88/88 [==============================] - 85s 968ms/step - loss: 1.0612 - accuracy: 0.6233 - val_loss: 1.8260 - val_accuracy: 0.5602
# Epoch 4/200
# 88/88 [==============================] - 278s 3s/step - loss: 0.9299 - accuracy: 0.6734 - val_loss: 1.5046 - val_accuracy: 0.6060
# Epoch 5/200
# 88/88 [==============================] - 332s 4s/step - loss: 0.8387 - accuracy: 0.7038 - val_loss: 1.2191 - val_accuracy: 0.5868
# Epoch 6/200
# 88/88 [==============================] - 303s 3s/step - loss: 0.7711 - accuracy: 0.7285 - val_loss: 1.0640 - val_accuracy: 0.6266
# Epoch 7/200
# 88/88 [==============================] - 283s 3s/step - loss: 0.7014 - accuracy: 0.7519 - val_loss: 0.8356 - val_accuracy: 0.6998
# Epoch 8/200
# 88/88 [==============================] - 726s 8s/step - loss: 0.6468 - accuracy: 0.7718 - val_loss: 0.7510 - val_accuracy: 0.7412
# Epoch 9/200
# 88/88 [==============================] - 386s 4s/step - loss: 0.5945 - accuracy: 0.7886 - val_loss: 0.8697 - val_accuracy: 0.7120
# Epoch 10/200
# 88/88 [==============================] - 362s 4s/step - loss: 0.5545 - accuracy: 0.8062 - val_loss: 0.9844 - val_accuracy: 0.7022
# Epoch 11/200
# 88/88 [==============================] - 328s 4s/step - loss: 0.5124 - accuracy: 0.8182 - val_loss: 0.6842 - val_accuracy: 0.7708
# Epoch 12/200
# 88/88 [==============================] - 331s 4s/step - loss: 0.4824 - accuracy: 0.8276 - val_loss: 0.7336 - val_accuracy: 0.7592
# Epoch 13/200
# 88/88 [==============================] - 383s 4s/step - loss: 0.4401 - accuracy: 0.8450 - val_loss: 0.7035 - val_accuracy: 0.7716
# Epoch 14/200
# 88/88 [==============================] - 358s 4s/step - loss: 0.4099 - accuracy: 0.8536 - val_loss: 0.7355 - val_accuracy: 0.7658
# Epoch 15/200
# 88/88 [==============================] - 348s 4s/step - loss: 0.3880 - accuracy: 0.8616 - val_loss: 0.7562 - val_accuracy: 0.7610
# Epoch 16/200
# 88/88 [==============================] - 373s 4s/step - loss: 0.3636 - accuracy: 0.8722 - val_loss: 0.7538 - val_accuracy: 0.7660
# Finished model training in 4998s
# Model performance with training set
# 1407/1407 [==============================] - 208s 148ms/step - loss: 0.2117 - accuracy: 0.9273
# Evaluating model performance with validation set
# 157/157 [==============================] - 16s 102ms/step - loss: 0.7538 - accuracy: 0.7660
# 313/313 [==============================] - 44s 141ms/step - loss: 0.7832 - accuracy: 0.7634
#
#
# test set accuracy:  76.34000182151794

# %% [markdown]
# ## Predictions

# %%
preds = model.predict(x_test_norm)
print('shape of preds: ', preds.shape)
# Out:
# shape of preds:  (10000, 10)

# %% [markdown]
# ## Plotting Performance Metrics
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#      loss  accuracy  val_loss  val_accuracy
# 13  0.604     0.830     0.726         0.788
# 14  0.581     0.835     0.714         0.799
# 15  0.572     0.840     0.749         0.790
# 16  0.550     0.848     0.709         0.798
# 17  0.539     0.852     0.769         0.785

# %%
losses = history.history['loss']
accs = history.history['accuracy']
val_losses = history.history['val_loss']
val_accs = history.history['val_accuracy']
epochs = len(losses)

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= model.predict(x_test_norm)
pred1=np.argmax(pred1, axis=1)

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.79      0.82      1000
#            1       0.92      0.88      0.90      1000
#            2       0.69      0.69      0.69      1000
#            3       0.58      0.64      0.61      1000
#            4       0.70      0.81      0.75      1000
#            5       0.84      0.51      0.63      1000
#            6       0.68      0.93      0.78      1000
#            7       0.89      0.78      0.83      1000
#            8       0.88      0.89      0.88      1000
#            9       0.87      0.88      0.87      1000
#
#     accuracy                           0.78     10000
#    macro avg       0.79      0.78      0.78     10000
# weighted avg       0.79      0.78      0.78     10000
#
# Accuracy Score: 0.7778
# Root Mean Square Error: 1.8232388762858256

# %%
plot_confusion_matrix(y_test,pred1)

# %% [markdown]
# ### Load HDF5 Model Format

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.models.load_model</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/models/load_model</div>

# %%
# model = tf.keras.models.load_model('/content/gdrive/My Drive/Colab Notebooks/models/model_0.8072.h5')
# model = tf.keras.models.load_model('./model_0.7986.h5')

# %%
preds = model.predict(x_test_norm)

# %%
preds.shape
# Out:
# (10000, 10)

# %% [markdown]
# ### Predictions

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

# %%
df = pd.DataFrame(preds[0:20], columns = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
df.style.format("{:.2%}").background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_8078d_row0_col0, #T_8078d_row0_col1, #T_8078d_row0_col2, #T_8078d_row0_col4, #T_8078d_row0_col6, #T_8078d_row0_col7, #T_8078d_row0_col9, #T_8078d_row1_col0, #T_8078d_row1_col2, #T_8078d_row1_col3, #T_8078d_row1_col4, #T_8078d_row1_col5, #T_8078d_row1_col6, #T_8078d_row1_col7, #T_8078d_row1_col9, #T_8078d_row2_col2, #T_8078d_row2_col3, #T_8078d_row2_col4, #T_8078d_row2_col5, #T_8078d_row2_col6, #T_8078d_row2_col7, #T_8078d_row3_col1, #T_8078d_row3_col3, #T_8078d_row3_col4, #T_8078d_row3_col5, #T_8078d_row3_col6, #T_8078d_row3_col7, #T_8078d_row3_col9, #T_8078d_row4_col0, #T_8078d_row4_col1, #T_8078d_row4_col3, #T_8078d_row4_col5, #T_8078d_row4_col7, #T_8078d_row4_col8, #T_8078d_row4_col9, #T_8078d_row5_col0, #T_8078d_row5_col1, #T_8078d_row5_col2, #T_8078d_row5_col3, #T_8078d_row5_col4, #T_8078d_row5_col7, #T_8078d_row5_col8, #T_8078d_row5_col9, #T_8078d_row6_col0, #T_8078d_row6_col2, #T_8078d_row6_col4, #T_8078d_row6_col5, #T_8078d_row6_col6, #T_8078d_row6_col7, #T_8078d_row6_col8, #T_8078d_row7_col1, #T_8078d_row7_col7, #T_8078d_row7_col8, #T_8078d_row8_col0, #T_8078d_row8_col1, #T_8078d_row8_col7, #T_8078d_row8_col8, #T_8078d_row8_col9, #T_8078d_row9_col0, #T_8078d_row9_col2, #T_8078d_row9_col3, #T_8078d_row9_col4, #T_8078d_row9_col5, #T_8078d_row9_col6, #T_8078d_row9_col7, #T_8078d_row10_col1, #T_8078d_row10_col6, #T_8078d_row10_col9, #T_8078d_row11_col0, #T_8078d_row11_col1, #T_8078d_row11_col2, #T_8078d_row11_col3, #T_8078d_row11_col4, #T_8078d_row11_col5, #T_8078d_row11_col6, #T_8078d_row11_col7, #T_8078d_row11_col8, #T_8078d_row12_col0, #T_8078d_row12_col1, #T_8078d_row12_col6, #T_8078d_row12_col8, #T_8078d_row12_col9, #T_8078d_row13_col0, #T_8078d_row13_col1, #T_8078d_row13_col2, #T_8078d_row13_col3, #T_8078d_row13_col4, #T_8078d_row13_col5, #T_8078d_row13_col6, #T_8078d_row13_col8, #T_8078d_row13_col9, #T_8078d_row14_col0, #T_8078d_row14_col1, #T_8078d_row14_col2, #T_8078d_row14_col3, #T_8078d_row14_col4, #T_8078d_row14_col5, #T_8078d_row14_col6, #T_8078d_row14_col7, #T_8078d_row14_col8, #T_8078d_row15_col1, #T_8078d_row15_col3, #T_8078d_row15_col4, #T_8078d_row15_col5, #T_8078d_row15_col7, #T_8078d_row15_col9, #T_8078d_row16_col0, #T_8078d_row16_col1, #T_8078d_row16_col4, #T_8078d_row16_col6, #T_8078d_row16_col8, #T_8078d_row16_col9, #T_8078d_row17_col0, #T_8078d_row17_col8, #T_8078d_row18_col0, #T_8078d_row18_col1, #T_8078d_row18_col2, #T_8078d_row18_col3, #T_8078d_row18_col4, #T_8078d_row18_col5, #T_8078d_row18_col6, #T_8078d_row18_col7, #T_8078d_row18_col9, #T_8078d_row19_col0, #T_8078d_row19_col1, #T_8078d_row19_col2, #T_8078d_row19_col3, #T_8078d_row19_col4, #T_8078d_row19_col5, #T_8078d_row19_col7, #T_8078d_row19_col8, #T_8078d_row19_col9 {
#   background-color: #f0f1f2;
#   color: #000000;
# }
# #T_8078d_row0_col3, #T_8078d_row3_col0, #T_8078d_row4_col4, #T_8078d_row6_col1, #T_8078d_row7_col2, #T_8078d_row8_col3, #T_8078d_row11_col9, #T_8078d_row12_col5, #T_8078d_row13_col7, #T_8078d_row14_col9, #T_8078d_row18_col8, #T_8078d_row19_col6 {
#   background-color: #778ce4;
#   color: #f1f1f1;
# }
# #T_8078d_row0_col5, #T_8078d_row7_col0, #T_8078d_row8_col2, #T_8078d_row10_col8, #T_8078d_row15_col0, #T_8078d_row17_col6 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_8078d_row0_col8, #T_8078d_row3_col2, #T_8078d_row6_col3, #T_8078d_row7_col9, #T_8078d_row8_col6, #T_8078d_row9_col8, #T_8078d_row12_col7, #T_8078d_row17_col1 {
#   background-color: #f0f0f2;
#   color: #000000;
# }
# #T_8078d_row1_col1, #T_8078d_row17_col5 {
#   background-color: #e7e9f1;
#   color: #000000;
# }
# #T_8078d_row1_col8 {
#   background-color: #7f93e5;
#   color: #f1f1f1;
# }
# #T_8078d_row2_col0, #T_8078d_row2_col9, #T_8078d_row5_col5, #T_8078d_row8_col5, #T_8078d_row10_col7, #T_8078d_row15_col2, #T_8078d_row16_col2, #T_8078d_row16_col7 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_8078d_row2_col1, #T_8078d_row6_col9 {
#   background-color: #e5e7f1;
#   color: #000000;
# }
# #T_8078d_row2_col8 {
#   background-color: #8395e5;
#   color: #f1f1f1;
# }
# #T_8078d_row3_col8 {
#   background-color: #dadef0;
#   color: #000000;
# }
# #T_8078d_row4_col2 {
#   background-color: #e8e9f1;
#   color: #000000;
# }
# #T_8078d_row4_col6 {
#   background-color: #8597e5;
#   color: #f1f1f1;
# }
# #T_8078d_row5_col6 {
#   background-color: #788ce4;
#   color: #f1f1f1;
# }
# #T_8078d_row7_col3, #T_8078d_row8_col4, #T_8078d_row12_col4 {
#   background-color: #ecedf2;
#   color: #000000;
# }
# #T_8078d_row7_col4 {
#   background-color: #bac3ec;
#   color: #000000;
# }
# #T_8078d_row7_col5 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_8078d_row7_col6 {
#   background-color: #92a3e7;
#   color: #f1f1f1;
# }
# #T_8078d_row9_col1 {
#   background-color: #a4b1e9;
#   color: #000000;
# }
# #T_8078d_row9_col9 {
#   background-color: #bdc6ec;
#   color: #000000;
# }
# #T_8078d_row10_col0 {
#   background-color: #b0bbeb;
#   color: #000000;
# }
# #T_8078d_row10_col2 {
#   background-color: #e3e6f1;
#   color: #000000;
# }
# #T_8078d_row10_col3 {
#   background-color: #d1d6ee;
#   color: #000000;
# }
# #T_8078d_row10_col4 {
#   background-color: #b0bbea;
#   color: #000000;
# }
# #T_8078d_row10_col5 {
#   background-color: #d4d9ef;
#   color: #000000;
# }
# #T_8078d_row12_col2, #T_8078d_row12_col3 {
#   background-color: #ebedf2;
#   color: #000000;
# }
# #T_8078d_row15_col6 {
#   background-color: #ebecf2;
#   color: #000000;
# }
# #T_8078d_row15_col8 {
#   background-color: #7f92e5;
#   color: #f1f1f1;
# }
# #T_8078d_row16_col3 {
#   background-color: #e0e3f0;
#   color: #000000;
# }
# #T_8078d_row16_col5 {
#   background-color: #8295e5;
#   color: #f1f1f1;
# }
# #T_8078d_row17_col2 {
#   background-color: #cad1ee;
#   color: #000000;
# }
# #T_8078d_row17_col3 {
#   background-color: #d9deef;
#   color: #000000;
# }
# #T_8078d_row17_col4 {
#   background-color: #c4cced;
#   color: #000000;
# }
# #T_8078d_row17_col7 {
#   background-color: #b1bceb;
#   color: #000000;
# }
# #T_8078d_row17_col9 {
#   background-color: #e2e5f0;
#   color: #000000;
# }
# </style>
# <table id="T_8078d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >airplane</th>
#       <th class="col_heading level0 col1" >automobile</th>
#       <th class="col_heading level0 col2" >bird</th>
#       <th class="col_heading level0 col3" >cat</th>
#       <th class="col_heading level0 col4" >deer</th>
#       <th class="col_heading level0 col5" >dog</th>
#       <th class="col_heading level0 col6" >frog</th>
#       <th class="col_heading level0 col7" >horse</th>
#       <th class="col_heading level0 col8" >ship</th>
#       <th class="col_heading level0 col9" >truck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8078d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8078d_row0_col0" class="data row0 col0" >0.02%</td>
#       <td id="T_8078d_row0_col1" class="data row0 col1" >0.07%</td>
#       <td id="T_8078d_row0_col2" class="data row0 col2" >0.03%</td>
#       <td id="T_8078d_row0_col3" class="data row0 col3" >97.26%</td>
#       <td id="T_8078d_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_8078d_row0_col5" class="data row0 col5" >1.69%</td>
#       <td id="T_8078d_row0_col6" class="data row0 col6" >0.10%</td>
#       <td id="T_8078d_row0_col7" class="data row0 col7" >0.02%</td>
#       <td id="T_8078d_row0_col8" class="data row0 col8" >0.75%</td>
#       <td id="T_8078d_row0_col9" class="data row0 col9" >0.05%</td>
#     </tr>
#     <tr>
#       <th id="T_8078d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8078d_row1_col0" class="data row1 col0" >0.15%</td>
#       <td id="T_8078d_row1_col1" class="data row1 col1" >7.36%</td>
#       <td id="T_8078d_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_8078d_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_8078d_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_8078d_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_8078d_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_8078d_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_8078d_row1_col8" class="data row1 col8" >92.48%</td>
#       <td id="T_8078d_row1_col9" class=

# %%
(_,_), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

img = test_images[2004]
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

plt.imshow(img, cmap='viridis')
plt.axis('off')
plt.show()

# %%
# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[:8]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)
len(activations)
# Out:
# 8

# %%
layer_names = []
for layer in model.layers:
    layer_names.append(layer.name)
    
layer_names
# Out:
# ['conv2d',
#  'max_pooling2d',
#  'dropout',
#  'conv2d_1',
#  'max_pooling2d_1',
#  'dropout_1',
#  'conv2d_2',
#  'max_pooling2d_2',
#  'dropout_2',
#  'flatten',
#  'batch_normalization',
#  'dense',
#  'dense_1']

# %%
# These are the names of the layers, so can have them as part of our plot
layer_names = []
for layer in model.layers[:3]:
    layer_names.append(layer.name)

images_per_row = 16

# Now let's display our feature maps
for layer_name, layer_activation in zip(layer_names, activations):
    # This is the number of features in the feature map
    n_features = layer_activation.shape[-1]

    # The feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # We will tile the activation channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # We'll tile each filter into this big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # Post-process the feature to make it visually palatable
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show();
# Out:
# C:\Users\steve\miniconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide
