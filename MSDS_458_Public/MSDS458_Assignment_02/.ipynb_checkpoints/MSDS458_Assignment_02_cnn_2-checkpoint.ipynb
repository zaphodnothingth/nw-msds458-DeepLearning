# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/NorthwesternHeader.png?raw=1">

# %% [markdown]
# ## MSDS458 Research Assignment 02 - Part 1
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div><br>

# %% [markdown]
# The CIFAR-10 dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>The CIFAR-10 dataset</b><br>
# https://www.cs.toronto.edu/~kriz/cifar.html
#     </div>

# %% [markdown]
# ## Import packages needed

# %%
import datetime
import time
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ### Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.3.1

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.4.0

# %% [markdown]
# ### Mount Google Drive to Colab Environment

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ### Functions for Research Assignment

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ## Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.<br>
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# * Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
# * x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
# * y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)

# %% [markdown]
# ## EDA Training and Test Datasets
#
# * Imported 50000 examples for training and 10000 examples for test
# * Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t\t{}'.format(x_test.shape))
print('test_labels:\t\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# ### Review labels for training dataset

# %%
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# ### Plot Examples

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)
    
    x = x[indices]
    y = y[indices]
    
    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)
    
    x = x[indices]
    y = y[indices]
    
    y = tf.keras.utils.to_categorical(y)
    
    return x, y

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(train_images, train_labels)
x_preview, y_preview = get_three_classes(test_images, test_labels)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)
    
    x = x[indices]
    y = y[indices]
    p = p[indices]
    
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# ### Preprocessing Data for Model Development

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %% [markdown]
# ### Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# ### Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# ### Rescale Examples  {Train, Validation, Test}
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255

# %% [markdown]
# 1. Each element in each example is a pixel value
# 2. Pixel values range from 0 to 255
# 3. 0 = black
# 4. 255 = white

# %%
x_train_norm = x_train_split/255
x_valid_norm = x_valid_split/255
x_test_norm = x_test/255

# %% [markdown]
# ### RUN CELLS ABOVE

# %% [markdown]
# ## Create the Model

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/CNN_architecture_v4.png?raw=1">

# %% [markdown]
# ### Build CNN Model

# %% [markdown]
# We use a Sequential class defined in Keras to create our model. The first 9 layers Conv2D MaxPooling, Dropout handle feature learning.  The last 3 layers, handle classification

# %%
model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D((2, 2),strides=2))
model.add(layers.Dropout(0.3))
# model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
# model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
# model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.L2(0.001)))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 128)       3584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 512)       590336
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 18432)             73728
# _________________________________________________________________
# dense (Dense)                (None, 384)               7078272
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                3850
# =================================================================
# Total params: 7,749,770
# Trainable params: 7,712,906
# Non-trainable params: 36,864
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "CIFAR10.png", show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %% [markdown]
# ### Compiling the model

# %% [markdown]
# In addition to setting up our model architecture, we also need to define which algorithm should the model use in order to optimize the weights and biases as per the given data. We will use stochastic gradient descent.
#
# We also need to define a loss function. Think of this function as the difference between the predicted outputs and the actual outputs given in the dataset. This loss needs to be minimised in order to have a higher model accuracy. That's what the optimization algorithm essentially does - it minimises the loss during model training. For our multi-class classification problem, categorical cross entropy is commonly used.
#
# Finally, we will use the accuracy during training as a metric to keep track of as the model trains.

# %%
# model.compile(optimizer='adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
#               metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
config = tf.compat.v1.ConfigProto( device_count = {'GPU': 1 , 'CPU': 56} )

# %%
def compile_train_model(model, x_train, y_train, x_valid, y_valid, epochs=200):
  timestamp=int(time.time())
  
  # Compile
  model.compile(optimizer='rmsprop',
                loss = 'SparseCategoricalCrossentropy',
                metrics=['accuracy'])

  # Train
  start_time = time.time()
  history = model.fit(
    x_train,
    y_train,
    epochs=epochs,
    batch_size=512,
    validation_data=(x_valid, y_valid),
    verbose=2,
    callbacks=[    
        EarlyStopping(monitor='val_accuracy', patience=3),
        ModelCheckpoint('./models/cnn/2/model_{val_accuracy:.4f}.h5',
                               save_best_only=True,
                               save_weights_only=False,
                               monitor='val_accuracy')]
  )1
  end_time = time.time()
  second_elapsed = round(end_time - start_time)

  print(f'Finished model training in {second_elapsed}s')

  print('\nModel performance with training set')
  model.evaluate(x_train, y_train)

  print('\nEvaluating model performance with validation set')
  model.evaluate(x_valid, y_valid)

  return history, model

# %%
# Compile and train
history, model = compile_train_model(model,
                                     x_train_norm, y_train_split,
                                     x_valid_norm, y_valid_split
                                    )
# Out:
# Epoch 1/200
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2097s vs `on_train_batch_end` time: 0.4087s). Check your callbacks.
# 88/88 - 84s - loss: 0.8437 - accuracy: 0.8566 - val_loss: 1.2433 - val_accuracy: 0.7388
# Epoch 2/200
# 88/88 - 109s - loss: 0.7420 - accuracy: 0.8880 - val_loss: 1.2032 - val_accuracy: 0.7438
# Epoch 3/200
# 88/88 - 109s - loss: 0.7038 - accuracy: 0.8977 - val_loss: 1.2787 - val_accuracy: 0.7242
# Epoch 4/200
# 88/88 - 109s - loss: 0.6831 - accuracy: 0.9025 - val_loss: 1.1446 - val_accuracy: 0.7660
# Epoch 5/200
# 88/88 - 109s - loss: 0.6649 - accuracy: 0.9095 - val_loss: 1.2855 - val_accuracy: 0.7280
# Epoch 6/200
# 88/88 - 109s - loss: 0.6516 - accuracy: 0.9153 - val_loss: 1.3125 - val_accuracy: 0.7186
# Epoch 7/200
# 88/88 - 109s - loss: 0.6461 - accuracy: 0.9174 - val_loss: 1.2153 - val_accuracy: 0.7634
# Finished model training in 747s
# Model performance with training set
# 1407/1407 [==============================] - 45s 32ms/step - loss: 0.5134 - accuracy: 0.9707
# Evaluating model performance with validation set
# 157/157 [==============================] - 5s 32ms/step - loss: 1.2153 - accuracy: 0.7634

# %% [markdown]
# ### Validation Data
# Data on which to evaluate the loss and any model metrics at the end of each epoch<br>
# The model will not be trained on this data

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# In order to ensure that this is not a simple "memorization" by the machine, we should evaluate the performance on the test set. This is easy to do, we simply use the `evaluate` method on our model.

# %%
loss, accuracy = model.evaluate(x_test_norm, y_test)
print('test set accuracy: ', accuracy * 100)
# Out:
# 313/313 [==============================] - 8s 25ms/step - loss: 1.2415 - accuracy: 0.7529
# test set accuracy:  75.29000043869019

# %% [markdown]
# ### no regularizer

# %%
model_n = models.Sequential()
model_n.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model_n.add(layers.MaxPool2D((2, 2),strides=2))
model_n.add(layers.Dropout(0.3))
# model_n.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
# model_n.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
# model_n.add(layers.Dropout(0.3))
model_n.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model_n.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model_n.add(layers.Dropout(0.3))
model_n.add(layers.Flatten())
model_n.add(layers.BatchNormalization())
model_n.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=None))
model_n.add(layers.Dense(units=10, activation=tf.nn.softmax))

# Compile and train
history, model_n = compile_train_model(model_n,
                                     x_train_norm, y_train_split,
                                     x_valid_norm, y_valid_split
                                    )

print('\nEvaluating model performance with test set')
loss, accuracy = model_n.evaluate(x_test_norm, y_test)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1970s vs `on_train_batch_end` time: 4.8386s). Check your callbacks.
# 88/88 - 374s - loss: 1.7220 - accuracy: 0.4478 - val_loss: 2.2040 - val_accuracy: 0.1468
# Epoch 2/200
# 88/88 - 428s - loss: 1.0688 - accuracy: 0.6238 - val_loss: 2.1743 - val_accuracy: 0.3094
# Epoch 3/200
# 88/88 - 378s - loss: 0.8500 - accuracy: 0.7027 - val_loss: 2.1282 - val_accuracy: 0.2674
# Epoch 4/200
# 88/88 - 857s - loss: 0.6901 - accuracy: 0.7596 - val_loss: 1.9514 - val_accuracy: 0.4796
# Epoch 5/200
# 88/88 - 528s - loss: 0.5514 - accuracy: 0.8079 - val_loss: 1.5235 - val_accuracy: 0.6016
# Epoch 6/200
# 88/88 - 504s - loss: 0.4292 - accuracy: 0.8511 - val_loss: 1.0365 - val_accuracy: 0.6780
# Epoch 7/200
# 88/88 - 506s - loss: 0.3361 - accuracy: 0.8837 - val_loss: 0.9300 - val_accuracy: 0.6816
# Epoch 8/200
# 88/88 - 514s - loss: 0.2599 - accuracy: 0.9093 - val_loss: 1.0073 - val_accuracy: 0.7100
# Epoch 9/200
# 88/88 - 538s - loss: 0.2067 - accuracy: 0.9304 - val_loss: 1.0227 - val_accuracy: 0.7360
# Epoch 10/200
# 88/88 - 562s - loss: 0.1666 - accuracy: 0.9427 - val_loss: 1.0703 - val_accuracy: 0.7366
# Epoch 11/200
# 88/88 - 613s - loss: 0.1403 - accuracy: 0.9526 - val_loss: 1.0326 - val_accuracy: 0.7438
# Epoch 12/200
# 88/88 - 409s - loss: 0.1221 - accuracy: 0.9594 - val_loss: 1.1800 - val_accuracy: 0.7354
# Epoch 13/200
# 88/88 - 387s - loss: 0.1044 - accuracy: 0.9642 - val_loss: 1.2653 - val_accuracy: 0.7272
# Epoch 14/200
# 88/88 - 395s - loss: 0.0972 - accuracy: 0.9690 - val_loss: 1.2403 - val_accuracy: 0.7384
# Finished model training in 7066s
# Model performance with training set
# 1407/1407 [==============================] - 195s 139ms/step - loss: 0.0373 - accuracy: 0.9907
# Evaluating model performance with validation set
# 157/157 [==============================] - 24s 153ms/step - loss: 1.2403 - accuracy: 0.7384
# 313/313 [==============================] - 33s 105ms/step - loss: 1.2469 - accuracy: 0.7395
#
#
# test set accuracy:  73.94999861717224

# %% [markdown]
# ## Predictions

# %%
preds = model.predict(x_test_norm)
print('shape of preds: ', preds.shape)
# Out:
# shape of preds:  (10000, 10)

# %% [markdown]
# ## Plotting Performance Metrics
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#     loss  accuracy  val_loss  val_accuracy
# 2  0.704     0.898     1.279         0.724
# 3  0.683     0.903     1.145         0.766
# 4  0.665     0.909     1.285         0.728
# 5  0.652     0.915     1.312         0.719
# 6  0.646     0.917     1.215         0.763

# %%
losses = history.history['loss']
accs = history.history['accuracy']
val_losses = history.history['val_loss']
val_accs = history.history['val_accuracy']
epochs = len(losses)

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %% [markdown]
# ## Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= model.predict(x_test_norm)
pred1=np.argmax(pred1, axis=1)

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78      1000
#            1       0.88      0.84      0.86      1000
#            2       0.65      0.66      0.65      1000
#            3       0.66      0.45      0.54      1000
#            4       0.72      0.75      0.74      1000
#            5       0.57      0.79      0.66      1000
#            6       0.79      0.84      0.81      1000
#            7       0.83      0.79      0.81      1000
#            8       0.85      0.85      0.85      1000
#            9       0.89      0.77      0.82      1000
#
#     accuracy                           0.75     10000
#    macro avg       0.76      0.75      0.75     10000
# weighted avg       0.76      0.75      0.75     10000
#
# Accuracy Score: 0.7529
# Root Mean Square Error: 2.0292609492127913

# %%
plot_confusion_matrix(y_test,pred1)

# %% [markdown]
# ### Load HDF5 Model Format

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>tf.keras.models.load_model</b><br>
# https://www.tensorflow.org/api_docs/python/tf/keras/models/load_model</div>

# %%
# model = tf.keras.models.load_model('/content/gdrive/My Drive/Colab Notebooks/models/model_0.8072.h5')
# model = tf.keras.models.load_model('./model_0.7986.h5')

# %%
preds = model.predict(x_test_norm)

# %%
preds.shape
# Out:
# (10000, 10)

# %% [markdown]
# ### Predictions

# %%
cm = sns.light_palette((260, 75, 60), input="husl", as_cmap=True)

# %%
df = pd.DataFrame(preds[0:20], columns = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
df.style.format("{:.2%}").background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_41815_row0_col0 {
#   background-color: #dee1f0;
#   color: #000000;
# }
# #T_41815_row0_col1, #T_41815_row0_col4, #T_41815_row0_col7, #T_41815_row0_col8, #T_41815_row0_col9, #T_41815_row1_col0, #T_41815_row1_col1, #T_41815_row1_col2, #T_41815_row1_col3, #T_41815_row1_col4, #T_41815_row1_col5, #T_41815_row1_col6, #T_41815_row1_col7, #T_41815_row1_col9, #T_41815_row2_col3, #T_41815_row2_col4, #T_41815_row2_col5, #T_41815_row2_col6, #T_41815_row2_col7, #T_41815_row3_col1, #T_41815_row3_col3, #T_41815_row3_col4, #T_41815_row3_col5, #T_41815_row3_col6, #T_41815_row3_col7, #T_41815_row3_col9, #T_41815_row4_col0, #T_41815_row4_col1, #T_41815_row4_col3, #T_41815_row4_col5, #T_41815_row4_col7, #T_41815_row4_col8, #T_41815_row4_col9, #T_41815_row5_col0, #T_41815_row5_col1, #T_41815_row5_col3, #T_41815_row5_col4, #T_41815_row5_col7, #T_41815_row5_col8, #T_41815_row5_col9, #T_41815_row6_col0, #T_41815_row6_col2, #T_41815_row6_col4, #T_41815_row6_col6, #T_41815_row6_col7, #T_41815_row6_col8, #T_41815_row6_col9, #T_41815_row7_col0, #T_41815_row7_col1, #T_41815_row7_col3, #T_41815_row7_col5, #T_41815_row7_col7, #T_41815_row7_col8, #T_41815_row7_col9, #T_41815_row8_col0, #T_41815_row8_col1, #T_41815_row8_col6, #T_41815_row8_col8, #T_41815_row8_col9, #T_41815_row9_col0, #T_41815_row9_col3, #T_41815_row9_col4, #T_41815_row9_col5, #T_41815_row9_col6, #T_41815_row9_col7, #T_41815_row10_col1, #T_41815_row10_col6, #T_41815_row10_col7, #T_41815_row10_col9, #T_41815_row11_col0, #T_41815_row11_col1, #T_41815_row11_col2, #T_41815_row11_col3, #T_41815_row11_col4, #T_41815_row11_col5, #T_41815_row11_col6, #T_41815_row11_col7, #T_41815_row11_col8, #T_41815_row12_col0, #T_41815_row12_col1, #T_41815_row12_col3, #T_41815_row12_col6, #T_41815_row12_col7, #T_41815_row12_col8, #T_41815_row12_col9, #T_41815_row13_col0, #T_41815_row13_col1, #T_41815_row13_col2, #T_41815_row13_col3, #T_41815_row13_col4, #T_41815_row13_col5, #T_41815_row13_col6, #T_41815_row13_col8, #T_41815_row13_col9, #T_41815_row14_col0, #T_41815_row14_col1, #T_41815_row14_col2, #T_41815_row14_col3, #T_41815_row14_col4, #T_41815_row14_col5, #T_41815_row14_col6, #T_41815_row14_col7, #T_41815_row14_col8, #T_41815_row15_col0, #T_41815_row15_col1, #T_41815_row15_col2, #T_41815_row15_col3, #T_41815_row15_col4, #T_41815_row15_col5, #T_41815_row15_col6, #T_41815_row15_col7, #T_41815_row15_col9, #T_41815_row16_col0, #T_41815_row16_col1, #T_41815_row16_col2, #T_41815_row16_col3, #T_41815_row16_col4, #T_41815_row16_col6, #T_41815_row16_col7, #T_41815_row16_col8, #T_41815_row16_col9, #T_41815_row17_col0, #T_41815_row17_col1, #T_41815_row17_col3, #T_41815_row17_col6, #T_41815_row17_col8, #T_41815_row17_col9, #T_41815_row18_col0, #T_41815_row18_col1, #T_41815_row18_col2, #T_41815_row18_col3, #T_41815_row18_col4, #T_41815_row18_col5, #T_41815_row18_col6, #T_41815_row18_col7, #T_41815_row18_col9, #T_41815_row19_col0, #T_41815_row19_col1, #T_41815_row19_col2, #T_41815_row19_col3, #T_41815_row19_col4, #T_41815_row19_col5, #T_41815_row19_col7, #T_41815_row19_col8, #T_41815_row19_col9 {
#   background-color: #f0f1f2;
#   color: #000000;
# }
# #T_41815_row0_col2, #T_41815_row2_col2, #T_41815_row4_col2, #T_41815_row5_col5, #T_41815_row17_col2 {
#   background-color: #f0f0f2;
#   color: #000000;
# }
# #T_41815_row0_col3, #T_41815_row4_col4 {
#   background-color: #8698e5;
#   color: #f1f1f1;
# }
# #T_41815_row0_col5 {
#   background-color: #ecedf2;
#   color: #000000;
# }
# #T_41815_row0_col6, #T_41815_row10_col8 {
#   background-color: #edeef2;
#   color: #000000;
# }
# #T_41815_row1_col8, #T_41815_row3_col0, #T_41815_row7_col2, #T_41815_row8_col3, #T_41815_row9_col1, #T_41815_row11_col9, #T_41815_row12_col4, #T_41815_row13_col7, #T_41815_row14_col9, #T_41815_row15_col8, #T_41815_row16_col5, #T_41815_row18_col8, #T_41815_row19_col6 {
#   background-color: #778ce4;
#   color: #f1f1f1;
# }
# #T_41815_row2_col0 {
#   background-color: #a2afe9;
#   color: #000000;
# }
# #T_41815_row2_col1, #T_41815_row8_col5 {
#   background-color: #ebecf2;
#   color: #000000;
# }
# #T_41815_row2_col8 {
#   background-color: #bbc4ec;
#   color: #000000;
# }
# #T_41815_row2_col9, #T_41815_row7_col4, #T_41815_row9_col2 {
#   background-color: #ebedf2;
#   color: #000000;
# }
# #T_41815_row3_col2 {
#   background-color: #b5bfeb;
#   color: #000000;
# }
# #T_41815_row3_col8 {
#   background-color: #e3e5f1;
#   color: #000000;
# }
# #T_41815_row4_col6 {
#   background-color: #bfc7ec;
#   color: #000000;
# }
# #T_41815_row5_col2, #T_41815_row6_col5, #T_41815_row8_col2, #T_41815_row8_col7, #T_41815_row9_col8 {
#   background-color: #eff0f2;
#   color: #000000;
# }
# #T_41815_row5_col6 {
#   background-color: #788de4;
#   color: #f1f1f1;
# }
# #T_41815_row6_col1 {
#   background-color: #b1bceb;
#   color: #000000;
# }
# #T_41815_row6_col3 {
#   background-color: #a1afe9;
#   color: #000000;
# }
# #T_41815_row7_col6 {
#   background-color: #a0aee9;
#   color: #000000;
# }
# #T_41815_row8_col4 {
#   background-color: #efeff2;
#   color: #000000;
# }
# #T_41815_row9_col9, #T_41815_row10_col3 {
#   background-color: #d4d9ef;
#   color: #000000;
# }
# #T_41815_row10_col0 {
#   background-color: #95a5e7;
#   color: #f1f1f1;
# }
# #T_41815_row10_col2 {
#   background-color: #e9eaf1;
#   color: #000000;
# }
# #T_41815_row10_col4, #T_41815_row12_col2 {
#   background-color: #dbdff0;
#   color: #000000;
# }
# #T_41815_row10_col5 {
#   background-color: #eaebf1;
#   color: #000000;
# }
# #T_41815_row12_col5 {
#   background-color: #d0d6ee;
#   color: #000000;
# }
# #T_41815_row17_col4 {
#   background-color: #bcc5ec;
#   color: #000000;
# }
# #T_41815_row17_col5 {
#   background-color: #eeeff2;
#   color: #000000;
# }
# #T_41815_row17_col7 {
#   background-color: #9dace8;
#   color: #000000;
# }
# </style>
# <table id="T_41815_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >airplane</th>
#       <th class="col_heading level0 col1" >automobile</th>
#       <th class="col_heading level0 col2" >bird</th>
#       <th class="col_heading level0 col3" >cat</th>
#       <th class="col_heading level0 col4" >deer</th>
#       <th class="col_heading level0 col5" >dog</th>
#       <th class="col_heading level0 col6" >frog</th>
#       <th class="col_heading level0 col7" >horse</th>
#       <th class="col_heading level0 col8" >ship</th>
#       <th class="col_heading level0 col9" >truck</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41815_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41815_row0_col0" class="data row0 col0" >11.52%</td>
#       <td id="T_41815_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_41815_row0_col2" class="data row0 col2" >0.24%</td>
#       <td id="T_41815_row0_col3" class="data row0 col3" >81.78%</td>
#       <td id="T_41815_row0_col4" class="data row0 col4" >0.03%</td>
#       <td id="T_41815_row0_col5" class="data row0 col5" >3.83%</td>
#       <td id="T_41815_row0_col6" class="data row0 col6" >2.51%</td>
#       <td id="T_41815_row0_col7" class="data row0 col7" >0.05%</td>
#       <td id="T_41815_row0_col8" class="data row0 col8" >0.02%</td>
#       <td id="T_41815_row0_col9" class="data row0 col9" >0.02%</td>
#     </tr>
#     <tr>
#       <th id="T_41815_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41815_row1_col0" class="data row1 col0" >0.12%</td>
#       <td id="T_41815_row1_col1" class="data row1 col1" >0.04%</td>
#       <td id="T_41815_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_41815_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_41815_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_41815_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_41815_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_41815_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_41815_row1_col8" class="data row1 col8" >99.84%</td>
#       <td id="T_41815_row1_col9" class="data row1 col9" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_41815_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41815_row2_col0" class="data row2 col0" >47.77%</td>
#       <td id="T_41815_row2_col1" class="data row2 col1" >

# %%
(_,_), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

img = test_images[2004]
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)

class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

plt.imshow(img, cmap='viridis')
plt.axis('off')
plt.show()

# %%
# Extracts the outputs of the top 8 layers:
layer_outputs = [layer.output for layer in model.layers[:8]]
# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(img_tensor)
len(activations)
# Out:
# 8

# %%
layer_names = []
for layer in model.layers:
    layer_names.append(layer.name)
    
layer_names
# Out:
# ['conv2d',
#  'max_pooling2d',
#  'dropout',
#  'conv2d_1',
#  'max_pooling2d_1',
#  'dropout_1',
#  'flatten',
#  'batch_normalization',
#  'dense',
#  'dense_1']

# %%
# These are the names of the layers, so can have them as part of our plot
layer_names = []
for layer in model.layers[:3]:
    layer_names.append(layer.name)

images_per_row = 16

# Now let's display our feature maps
for layer_name, layer_activation in zip(layer_names, activations):
    # This is the number of features in the feature map
    n_features = layer_activation.shape[-1]

    # The feature map has shape (1, size, size, n_features)
    size = layer_activation.shape[1]

    # We will tile the activation channels in this matrix
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))

    # We'll tile each filter into this big horizontal grid
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            # Post-process the feature to make it visually palatable
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
                         row * size : (row + 1) * size] = channel_image

    # Display the grid
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
    
plt.show();
# Out:
# C:\Users\steve\miniconda3\envs\tfgpu\lib\site-packages\ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# ### Experiment x

# %%
model = models.Sequential()
model.add(layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu,input_shape=(32, 32, 3)))
model.add(layers.MaxPool2D((2, 2),strides=2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(filters=256, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
model.add(layers.Dropout(0.3))
# model.add(layers.Conv2D(filters=512, kernel_size=(3, 3), strides=(1, 1), activation=tf.nn.relu))
# model.add(layers.MaxPool2D(pool_size=(2, 2),strides=2))
# model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.BatchNormalization())
model.add(layers.Dense(units=384, activation=tf.nn.relu,kernel_regularizer=tf.keras.regularizers.L2(0.001)))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# Compile and train
history, model_n = compile_train_model(model_n,
                                     x_train_norm, y_train_split,
                                     x_valid_norm, y_valid_split
                                    )

print('\nEvaluating model performance with test set')
loss, accuracy = model_n.evaluate(x_test_norm, y_test)
# Out:
# Epoch 1/200
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.2070s vs `on_train_batch_end` time: 0.4112s). Check your callbacks.
# 88/88 - 56s - loss: 0.1109 - accuracy: 0.9641 - val_loss: 1.2899 - val_accuracy: 0.7340
# Epoch 2/200
# 88/88 - 107s - loss: 0.0845 - accuracy: 0.9726 - val_loss: 1.3877 - val_accuracy: 0.7314
# Epoch 3/200
# 88/88 - 107s - loss: 0.0723 - accuracy: 0.9766 - val_loss: 1.5522 - val_accuracy: 0.7238
# Epoch 4/200
# 88/88 - 100s - loss: 0.0685 - accuracy: 0.9780 - val_loss: 1.3651 - val_accuracy: 0.7146
# Finished model training in 379s
# Model performance with training set
# 1407/1407 [==============================] - 30s 21ms/step - loss: 0.0586 - accuracy: 0.9820
# Evaluating model performance with validation set
# 157/157 [==============================] - 3s 21ms/step - loss: 1.3651 - accuracy: 0.7146
#
# Evaluating model performance with test set
# 313/313 [==============================] - 7s 21ms/step - loss: 1.3838 - accuracy: 0.7240
