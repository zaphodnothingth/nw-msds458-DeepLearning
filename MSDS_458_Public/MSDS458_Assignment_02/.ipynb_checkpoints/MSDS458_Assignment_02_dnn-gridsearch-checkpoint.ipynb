# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/NorthwesternHeader.png?raw=1">

# %% [markdown]
# ## MSDS458 Research Assignment 02 - Part 1
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div><br>

# %% [markdown]
# The CIFAR-10 dataset (Canadian Institute For Advanced Research) is a collection of images that are commonly used to train machine learning and computer vision algorithms. It is one of the most widely used datasets for machine learning research. The CIFAR-10 dataset contains 60,000 32x32 color images in 10 different classes. The 10 different classes represent airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. There are 6,000 images of each class.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>The CIFAR-10 dataset</b><br>
# https://www.cs.toronto.edu/~kriz/cifar.html
#     </div>

# %% [markdown]
# ## Import packages needed

# %%
import datetime
import time
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ### Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.3.1

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.4.0

# %% [markdown]
# ### Mount Google Drive to Colab Environment

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %% [markdown]
# ### Functions for Research Assignment

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ## Loading cifar10 Dataset
#
# The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.<br>
#
# The dataset is divided into five training batches and one test batch, each with 10000 images. The test batch contains exactly 1000 randomly-selected images from each class. The training batches contain the remaining images in random order, but some training batches may contain more images from one class than another. Between them, the training batches contain exactly 5000 images from each class.

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %% [markdown]
# * Tuple of Numpy arrays: (x_train, y_train), (x_test, y_test).
# * x_train, x_test: uint8 arrays of color image data with shapes (num_samples, 32, 32).
# * y_train, y_test: uint8 arrays of digit labels (integers in range 0-9)

# %% [markdown]
# ## EDA Training and Test Datasets
#
# * Imported 50000 examples for training and 10000 examples for test
# * Imported 50000 labels for training and 10000 labels for test

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t\t{}'.format(x_test.shape))
print('test_labels:\t\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:		(10000, 32, 32, 3)
# test_labels:		(10000, 1)

# %% [markdown]
# ### Review labels for training dataset

# %%
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
print("This output the numeric label, need to convert to item description")
# Out:
# First ten labels training dataset:
#  [[6]
#  [9]
#  [9]
#  [4]
#  [1]
#  [1]
#  [2]
#  [7]
#  [8]
#  [3]]
#
# This output the numeric label, need to convert to item description

# %% [markdown]
# ### Preprocessing Data for Model Development

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %% [markdown]
# ### Create Validation Data Set

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %% [markdown]
# ### Confirm Datasets {Train, Validation, Test}

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %% [markdown]
# ### Rescale Examples  {Train, Validation, Test}
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255

# %% [markdown]
# 1. Each element in each example is a pixel value
# 2. Pixel values range from 0 to 255
# 3. 0 = black
# 4. 255 = white

# %%
x_train_norm = x_train_split/255
x_valid_norm = x_valid_split/255
x_test_norm = x_test/255

# %%
# flatten
x_train_reshaped = np.reshape(x_train_norm, (45000,3072))
x_test_reshaped = np.reshape(x_test_norm, (10000, 3072))
x_valid_reshaped = np.reshape(x_valid_norm, (5000, 3072))

# %% [markdown]
# ### Experiment X: Gridsearch

# %%
import pandas as pd
import math

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
def FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes):
    layers = []
    
    nodes_increment = (last_layer_nodes - first_layer_nodes)/ (n_layers-1)
    nodes = first_layer_nodes
    for i in range(1, n_layers+1):
        layers.append(math.ceil(nodes))
        nodes = nodes + nodes_increment
    
    return layers

# %%
def createmodel(n_layers, first_layer_nodes, last_layer_nodes, activation_func, loss_func):
    print('\n\n\n\n\ncurrent params:\n\t', n_layers, first_layer_nodes, last_layer_nodes, activation_func, loss_func)
    model = Sequential()
    n_nodes = FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes)
    model.add(Dense(input_shape=[3072], units=784, activation=activation_func,kernel_regularizer=tf.keras.regularizers.L2(0.001)))
    for i in range(1, n_layers):
        model.add(Dense(n_nodes[i-1], activation=activation_func))
            
    model.add(Dense(10, activation=tf.nn.softmax))
    model.summary()
    model.compile(optimizer='adam', 
                  loss=loss_func, 
                  metrics = ["accuracy"]) #note: metrics could also be 'mse'
    
    return model

##Wrap model into scikit-learn
model =  KerasClassifier(build_fn=createmodel, verbose = True)

# %%
activation_funcs = ['sigmoid', 'relu', 'tanh'] 
loss_funcs = ['SparseCategoricalCrossentropy']

param_grid = dict(n_layers=[2,3]
                  , first_layer_nodes = [512, 384]
                  , last_layer_nodes = [128]
                  , activation_func = activation_funcs
                  , loss_func = loss_funcs
                  , batch_size = [512]
                  , epochs = [200])

grid = GridSearchCV(estimator = model, param_grid = param_grid)

# %%
start_time = time.time()

grid.fit(
    x_train_reshaped
    ,y_train_split
    ,validation_data=(x_valid_reshaped, y_valid_split)
    ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=2)] 
)

end_time = time.time()
second_elapsed = round(end_time - start_time)
print(f'Finished model training in {second_elapsed}s')
# Out:
# current params:
# 	 2 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_61"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_213 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_214 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_215 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 2,816,282
# Trainable params: 2,816,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 3s 49ms/step - loss: 2.6088 - accuracy: 0.2521 - val_loss: 2.2230 - val_accuracy: 0.2426
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9850 - accuracy: 0.3273 - val_loss: 1.9425 - val_accuracy: 0.3170
# Epoch 3/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.9034 - accuracy: 0.3491 - val_loss: 1.8552 - val_accuracy: 0.3630
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8530 - accuracy: 0.3664 - val_loss: 1.8565 - val_accuracy: 0.3498
# Epoch 5/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.8286 - accuracy: 0.3747 - val_loss: 1.8039 - val_accuracy: 0.3850
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8174 - accuracy: 0.3783 - val_loss: 1.8240 - val_accuracy: 0.3670
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7898 - accuracy: 0.3946 - val_loss: 1.7687 - val_accuracy: 0.3962
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7752 - accuracy: 0.3975 - val_loss: 1.7820 - val_accuracy: 0.3912
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7543 - accuracy: 0.4082 - val_loss: 1.7453 - val_accuracy: 0.4112
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7322 - accuracy: 0.4178 - val_loss: 1.7361 - val_accuracy: 0.4062
# Epoch 11/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7106 - accuracy: 0.4260 - val_loss: 1.7908 - val_accuracy: 0.3922
# 18/18 [==============================] - 0s 13ms/step - loss: 1.7569 - accuracy: 0.4057
#
#
#
#
#
# current params:
# 	 2 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_216 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_217 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_218 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 2,816,282
# Trainable params: 2,816,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 32ms/step - loss: 2.5845 - accuracy: 0.2553 - val_loss: 2.1112 - val_accuracy: 0.3134
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9623 - accuracy: 0.3363 - val_loss: 1.9382 - val_accuracy: 0.3190
# Epoch 3/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.8797 - accuracy: 0.3589 - val_loss: 1.8868 - val_accuracy: 0.3452
# Epoch 4/200
# 71/71 [==============================] - 4s 63ms/step - loss: 1.8514 - accuracy: 0.3676 - val_loss: 1.8400 - val_accuracy: 0.3716
# Epoch 5/200
# 71/71 [==============================] - 4s 59ms/step - loss: 1.8141 - accuracy: 0.3817 - val_loss: 1.8921 - val_accuracy: 0.3372
# Epoch 6/200
# 71/71 [==============================] - 6s 88ms/step - loss: 1.8076 - accuracy: 0.3861 - val_loss: 1.7911 - val_accuracy: 0.3962
# Epoch 7/200
# 71/71 [==============================] - 6s 87ms/step - loss: 1.7689 - accuracy: 0.4006 - val_loss: 1.8102 - val_accuracy: 0.3794
# Epoch 8/200
# 71/71 [==============================] - 6s 87ms/step - loss: 1.7751 - accuracy: 0.3986 - val_loss: 1.8830 - val_accuracy: 0.3710
# 18/18 [==============================] - 0s 11ms/step - loss: 1.8699 - accuracy: 0.3802
#
#
#
#
#
# current params:
# 	 2 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_219 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_220 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_221 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 2,816,282
# Trainable params: 2,816,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.6074 - accuracy: 0.2513 - val_loss: 2.0520 - val_accuracy: 0.3112
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9570 - accuracy: 0.3364 - val_loss: 1.9883 - val_accuracy: 0.3102
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8818 - accuracy: 0.3565 - val_loss: 1.8823 - val_accuracy: 0.3500
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8440 - accuracy: 0.3689 - val_loss: 1.8508 - val_accuracy: 0.3702
# Epoch 5/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8106 - accuracy: 0.3840 - val_loss: 1.8402 - val_accuracy: 0.3650
# Epoch 6/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7975 - accuracy: 0.3873 - val_loss: 1.8332 - val_accuracy: 0.3708
# Epoch 7/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7856 - accuracy: 0.3924 - val_loss: 1.8595 - val_accuracy: 0.3522
# Epoch 8/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7594 - accuracy: 0.4071 - val_loss: 1.8030 - val_accuracy: 0.3798
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7375 - accuracy: 0.4146 - val_loss: 1.7692 - val_accuracy: 0.3904
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7211 - accuracy: 0.4175 - val_loss: 1.7442 - val_accuracy: 0.4088
# Epoch 11/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7132 - accuracy: 0.4219 - val_loss: 1.7497 - val_accuracy: 0.4010
# Epoch 12/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6957 - accuracy: 0.4312 - val_loss: 1.7124 - val_accuracy: 0.4226
# Epoch 13/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6798 - accuracy: 0.4393 - val_loss: 1.7396 - val_accuracy: 0.4036
# Epoch 14/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6926 - accuracy: 0.4330 - val_loss: 1.7230 - val_accuracy: 0.4136
# 18/18 [==============================] - 0s 15ms/step - loss: 1.7121 - accuracy: 0.4317
#
#
#
#
#
# current params:
# 	 2 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_64"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_222 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_223 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_224 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 2,816,282
# Trainable params: 2,816,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 2.6366 - accuracy: 0.2463 - val_loss: 2.0736 - val_accuracy: 0.3258
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9735 - accuracy: 0.3298 - val_loss: 1.9592 - val_accuracy: 0.3202
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8926 - accuracy: 0.3500 - val_loss: 1.9058 - val_accuracy: 0.3342
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8545 - accuracy: 0.3638 - val_loss: 1.8723 - val_accuracy: 0.3508
# Epoch 5/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.8128 - accuracy: 0.3833 - val_loss: 1.8898 - val_accuracy: 0.3352
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8089 - accuracy: 0.3847 - val_loss: 1.8764 - val_accuracy: 0.3550
# Epoch 7/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.7756 - accuracy: 0.3974 - val_loss: 1.8205 - val_accuracy: 0.3714
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7649 - accuracy: 0.3991 - val_loss: 1.8177 - val_accuracy: 0.3726
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7515 - accuracy: 0.4075 - val_loss: 1.7711 - val_accuracy: 0.4050
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7327 - accuracy: 0.4148 - val_loss: 1.7664 - val_accuracy: 0.3930
# Epoch 11/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7276 - accuracy: 0.4129 - val_loss: 1.7502 - val_accuracy: 0.4010
# 18/18 [==============================] - 0s 15ms/step - loss: 1.7339 - accuracy: 0.4086
#
#
#
#
#
# current params:
# 	 2 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_65"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_225 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_226 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_227 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 2,816,282
# Trainable params: 2,816,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 6s 88ms/step - loss: 2.6614 - accuracy: 0.2453 - val_loss: 2.0984 - val_accuracy: 0.3092
# Epoch 2/200
# 71/71 [==============================] - 6s 88ms/step - loss: 1.9815 - accuracy: 0.3315 - val_loss: 1.9212 - val_accuracy: 0.3462
# Epoch 3/200
# 71/71 [==============================] - 6s 88ms/step - loss: 1.8886 - accuracy: 0.3561 - val_loss: 1.9071 - val_accuracy: 0.3416
# Epoch 4/200
# 71/71 [==============================] - 6s 89ms/step - loss: 1.8513 - accuracy: 0.3670 - val_loss: 1.9347 - val_accuracy: 0.3226
# 18/18 [==============================] - 0s 11ms/step - loss: 1.9286 - accuracy: 0.3326
#
#
#
#
#
# current params:
# 	 3 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_66"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_228 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_229 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_230 (Dense)            (None, 320)               164160
# _________________________________________________________________
# dense_231 (Dense)            (None, 10)                3210
# =================================================================
# Total params: 2,978,522
# Trainable params: 2,978,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 34ms/step - loss: 2.3737 - accuracy: 0.2261 - val_loss: 2.0238 - val_accuracy: 0.2728
# Epoch 2/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.9600 - accuracy: 0.3053 - val_loss: 1.9428 - val_accuracy: 0.3060
# Epoch 3/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.9104 - accuracy: 0.3286 - val_loss: 1.8876 - val_accuracy: 0.3322
# Epoch 4/200
# 71/71 [==============================] - 2s 33ms/step - loss: 1.8878 - accuracy: 0.3398 - val_loss: 1.8752 - val_accuracy: 0.3410
# Epoch 5/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.8449 - accuracy: 0.3541 - val_loss: 1.8305 - val_accuracy: 0.3544
# Epoch 6/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.8301 - accuracy: 0.3615 - val_loss: 1.8875 - val_accuracy: 0.3260
# Epoch 7/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.8067 - accuracy: 0.3704 - val_loss: 1.8313 - val_accuracy: 0.3632
# Epoch 8/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.8035 - accuracy: 0.3724 - val_loss: 1.8238 - val_accuracy: 0.3586
# Epoch 9/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7829 - accuracy: 0.3814 - val_loss: 1.8163 - val_accuracy: 0.3684
# Epoch 10/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7674 - accuracy: 0.3850 - val_loss: 1.7955 - val_accuracy: 0.3706
# Epoch 11/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7506 - accuracy: 0.3957 - val_loss: 1.8142 - val_accuracy: 0.3630
# Epoch 12/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7732 - accuracy: 0.3897 - val_loss: 1.7497 - val_accuracy: 0.3980
# Epoch 13/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7138 - accuracy: 0.4127 - val_loss: 1.7446 - val_accuracy: 0.3980
# Epoch 14/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7287 - accuracy: 0.4092 - val_loss: 1.7389 - val_accuracy: 0.4036
# Epoch 15/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7024 - accuracy: 0.4227 - val_loss: 1.7478 - val_accuracy: 0.4036
# Epoch 16/200
# 71/71 [==============================] - 2s 33ms/step - loss: 1.6949 - accuracy: 0.4210 - val_loss: 1.7137 - val_accuracy: 0.4104
# Epoch 17/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.6721 - accuracy: 0.4333 - val_loss: 1.7110 - val_accuracy: 0.4200
# Epoch 18/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.6733 - accuracy: 0.4301 - val_loss: 1.6847 - val_accuracy: 0.4204
# Epoch 19/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.6808 - accuracy: 0.4301 - val_loss: 1.7001 - val_accuracy: 0.4170
# Epoch 20/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.6437 - accuracy: 0.4446 - val_loss: 1.7329 - val_accuracy: 0.4216
# Epoch 21/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.6442 - accuracy: 0.4451 - val_loss: 1.7697 - val_accuracy: 0.3958
# Epoch 22/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.6335 - accuracy: 0.4459 - val_loss: 1.7265 - val_accuracy: 0.4150
# 18/18 [==============================] - 0s 14ms/step - loss: 1.6936 - accuracy: 0.4281
#
#
#
#
#
# current params:
# 	 3 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_67"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_232 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_233 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_234 (Dense)            (None, 320)               164160
# _________________________________________________________________
# dense_235 (Dense)            (None, 10)                3210
# =================================================================
# Total params: 2,978,522
# Trainable params: 2,978,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 34ms/step - loss: 2.4129 - accuracy: 0.2011 - val_loss: 2.0424 - val_accuracy: 0.2752
# Epoch 2/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.9720 - accuracy: 0.2921 - val_loss: 1.9731 - val_accuracy: 0.3012
# Epoch 3/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.9176 - accuracy: 0.3267 - val_loss: 1.9046 - val_accuracy: 0.3190
# Epoch 4/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.8706 - accuracy: 0.3481 - val_loss: 1.8482 - val_accuracy: 0.3516
# Epoch 5/200
# 71/71 [==============================] - 2s 33ms/step - loss: 1.8488 - accuracy: 0.3504 - val_loss: 1.8790 - val_accuracy: 0.3392
# Epoch 6/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.8196 - accuracy: 0.3631 - val_loss: 1.9552 - val_accuracy: 0.3362
# 18/18 [==============================] - 0s 15ms/step - loss: 1.9367 - accuracy: 0.3423
#
#
#
#
#
# current params:
# 	 3 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_68"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_236 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_237 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_238 (Dense)            (None, 320)               164160
# _________________________________________________________________
# dense_239 (Dense)            (None, 10)                3210
# =================================================================
# Total params: 2,978,522
# Trainable params: 2,978,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 33ms/step - loss: 2.4099 - accuracy: 0.2057 - val_loss: 2.1035 - val_accuracy: 0.2406
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9818 - accuracy: 0.2955 - val_loss: 1.9340 - val_accuracy: 0.3158
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9142 - accuracy: 0.3258 - val_loss: 1.9458 - val_accuracy: 0.3146
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8900 - accuracy: 0.3361 - val_loss: 1.8664 - val_accuracy: 0.3420
# Epoch 5/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.8526 - accuracy: 0.3497 - val_loss: 1.8789 - val_accuracy: 0.3454
# Epoch 6/200
# 71/71 [==============================] - 2s 33ms/step - loss: 1.8276 - accuracy: 0.3652 - val_loss: 1.8484 - val_accuracy: 0.3528
# Epoch 7/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.8259 - accuracy: 0.3652 - val_loss: 1.8375 - val_accuracy: 0.3612
# Epoch 8/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7946 - accuracy: 0.3750 - val_loss: 1.8287 - val_accuracy: 0.3516
# Epoch 9/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7838 - accuracy: 0.3811 - val_loss: 1.7917 - val_accuracy: 0.3760
# Epoch 10/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7565 - accuracy: 0.3906 - val_loss: 1.8179 - val_accuracy: 0.3732
# Epoch 11/200
# 71/71 [==============================] - 2s 32ms/step - loss: 1.7705 - accuracy: 0.3867 - val_loss: 1.8561 - val_accuracy: 0.3634
# 18/18 [==============================] - 0s 13ms/step - loss: 1.8415 - accuracy: 0.3570
#
#
#
#
#
# current params:
# 	 3 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_69"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_240 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_241 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_242 (Dense)            (None, 320)               164160
# _________________________________________________________________
# dense_243 (Dense)            (None, 10)                3210
# =================================================================
# Total params: 2,978,522
# Trainable params: 2,978,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 7s 93ms/step - loss: 2.4341 - accuracy: 0.1906 - val_loss: 2.0759 - val_accuracy: 0.2330
# Epoch 2/200
# 71/71 [==============================] - 6s 90ms/step - loss: 1.9931 - accuracy: 0.2823 - val_loss: 1.9574 - val_accuracy: 0.3112
# Epoch 3/200
# 71/71 [==============================] - 6s 91ms/step - loss: 1.9279 - accuracy: 0.3182 - val_loss: 1.9655 - val_accuracy: 0.3046
# Epoch 4/200
# 71/71 [==============================] - 6s 90ms/step - loss: 1.8946 - accuracy: 0.3298 - val_loss: 1.8661 - val_accuracy: 0.3342
# Epoch 5/200
# 71/71 [==============================] - 6s 91ms/step - loss: 1.8555 - accuracy: 0.3489 - val_loss: 1.8363 - val_accuracy: 0.3524
# Epoch 6/200
# 71/71 [==============================] - 6s 90ms/step - loss: 1.8234 - accuracy: 0.3609 - val_loss: 1.8326 - val_accuracy: 0.3572
# Epoch 7/200
# 71/71 [==============================] - 9s 120ms/step - loss: 1.8270 - accuracy: 0.3645 - val_loss: 1.7999 - val_accuracy: 0.3700
# Epoch 8/200
# 71/71 [==============================] - 6s 91ms/step - loss: 1.7863 - accuracy: 0.3806 - val_loss: 1.8091 - val_accuracy: 0.3676
# Epoch 9/200
# 71/71 [==============================] - 6s 91ms/step - loss: 1.7729 - accuracy: 0.3835 - val_loss: 1.7829 - val_accuracy: 0.3792
# Epoch 10/200
# 71/71 [==============================] - 6s 90ms/step - loss: 1.7647 - accuracy: 0.3923 - val_loss: 1.8354 - val_accuracy: 0.3682
# Epoch 11/200
# 71/71 [==============================] - 9s 120ms/step - loss: 1.7587 - accuracy: 0.3957 - val_loss: 1.7346 - val_accuracy: 0.4026
# Epoch 12/200
# 71/71 [==============================] - 6s 91ms/step - loss: 1.7372 - accuracy: 0.4021 - val_loss: 1.7372 - val_accuracy: 0.4004
# Epoch 13/200
# 71/71 [==============================] - 6s 91ms/step - loss: 1.7169 - accuracy: 0.4110 - val_loss: 1.7454 - val_accuracy: 0.3992
# 18/18 [==============================] - 2s 134ms/step - loss: 1.7267 - accuracy: 0.4113
#
#
#
#
#
# current params:
# 	 3 512 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_70"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_244 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_245 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_246 (Dense)            (None, 320)               164160
# _________________________________________________________________
# dense_247 (Dense)            (None, 10)                3210
# =================================================================
# Total params: 2,978,522
# Trainable params: 2,978,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 7s 94ms/step - loss: 2.4350 - accuracy: 0.1971 - val_loss: 2.0651 - val_accuracy: 0.2762
# Epoch 2/200
# 71/71 [==============================] - 9s 120ms/step - loss: 1.9740 - accuracy: 0.3018 - val_loss: 1.9647 - val_accuracy: 0.2910
# Epoch 3/200
# 71/71 [==============================] - 6s 91ms/step - loss: 1.9239 - accuracy: 0.3204 - val_loss: 1.8798 - val_accuracy: 0.3438
# Epoch 4/200
# 71/71 [==============================] - 6s 90ms/step - loss: 1.8758 - accuracy: 0.3449 - val_loss: 1.9028 - val_accuracy: 0.3370
# Epoch 5/200
# 71/71 [==============================] - 6s 89ms/step - loss: 1.8493 - accuracy: 0.3549 - val_loss: 1.9675 - val_accuracy: 0.3188
# 18/18 [==============================] - 2s 134ms/step - loss: 1.9645 - accuracy: 0.3214
#
#
#
#
#
# current params:
# 	 2 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_71"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_248 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_249 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_250 (Dense)            (None, 10)                3850
# =================================================================
# Total params: 2,714,522
# Trainable params: 2,714,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 6s 90ms/step - loss: 2.6685 - accuracy: 0.2448 - val_loss: 2.0776 - val_accuracy: 0.3208
# Epoch 2/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.9934 - accuracy: 0.3306 - val_loss: 1.9851 - val_accuracy: 0.3158
# Epoch 3/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.9064 - accuracy: 0.3461 - val_loss: 2.0133 - val_accuracy: 0.3082
# 18/18 [==============================] - 0s 13ms/step - loss: 1.9954 - accuracy: 0.3098
#
#
#
#
#
# current params:
# 	 2 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_72"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_251 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_252 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_253 (Dense)            (None, 10)                3850
# =================================================================
# Total params: 2,714,522
# Trainable params: 2,714,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 2.5939 - accuracy: 0.2604 - val_loss: 2.1314 - val_accuracy: 0.2942
# Epoch 2/200
# 71/71 [==============================] - 2s 28ms/step - loss: 1.9743 - accuracy: 0.3373 - val_loss: 1.9956 - val_accuracy: 0.3110
# Epoch 3/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8948 - accuracy: 0.3551 - val_loss: 1.9351 - val_accuracy: 0.3324
# Epoch 4/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8531 - accuracy: 0.3676 - val_loss: 1.8678 - val_accuracy: 0.3468
# Epoch 5/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8221 - accuracy: 0.3787 - val_loss: 1.8335 - val_accuracy: 0.3700
# Epoch 6/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8128 - accuracy: 0.3791 - val_loss: 1.8828 - val_accuracy: 0.3512
# Epoch 7/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8031 - accuracy: 0.3894 - val_loss: 1.9315 - val_accuracy: 0.3380
# 18/18 [==============================] - 0s 14ms/step - loss: 1.9149 - accuracy: 0.3473
#
#
#
#
#
# current params:
# 	 2 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_73"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_254 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_255 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_256 (Dense)            (None, 10)                3850
# =================================================================
# Total params: 2,714,522
# Trainable params: 2,714,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 2.6187 - accuracy: 0.2396 - val_loss: 2.0593 - val_accuracy: 0.3048
# Epoch 2/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.9701 - accuracy: 0.3312 - val_loss: 1.9735 - val_accuracy: 0.3098
# Epoch 3/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8855 - accuracy: 0.3560 - val_loss: 1.8663 - val_accuracy: 0.3506
# Epoch 4/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8489 - accuracy: 0.3683 - val_loss: 1.8863 - val_accuracy: 0.3524
# Epoch 5/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8228 - accuracy: 0.3767 - val_loss: 1.8498 - val_accuracy: 0.3602
# Epoch 6/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7936 - accuracy: 0.3926 - val_loss: 1.8700 - val_accuracy: 0.3546
# Epoch 7/200
# 71/71 [==============================] - 2s 28ms/step - loss: 1.8129 - accuracy: 0.3817 - val_loss: 1.8353 - val_accuracy: 0.3706
# Epoch 8/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7754 - accuracy: 0.3999 - val_loss: 1.8396 - val_accuracy: 0.3586
# Epoch 9/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7534 - accuracy: 0.4067 - val_loss: 1.8261 - val_accuracy: 0.3854
# Epoch 10/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7456 - accuracy: 0.4117 - val_loss: 1.7986 - val_accuracy: 0.3904
# Epoch 11/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7419 - accuracy: 0.4147 - val_loss: 1.8233 - val_accuracy: 0.3638
# Epoch 12/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7267 - accuracy: 0.4194 - val_loss: 1.7538 - val_accuracy: 0.3946
# Epoch 13/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7089 - accuracy: 0.4261 - val_loss: 1.8236 - val_accuracy: 0.3754
# Epoch 14/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7058 - accuracy: 0.4258 - val_loss: 1.8075 - val_accuracy: 0.3742
# 18/18 [==============================] - 0s 14ms/step - loss: 1.8040 - accuracy: 0.3788
#
#
#
#
#
# current params:
# 	 2 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_74"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_257 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_258 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_259 (Dense)            (None, 10)                3850
# =================================================================
# Total params: 2,714,522
# Trainable params: 2,714,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 2.5754 - accuracy: 0.2606 - val_loss: 2.0511 - val_accuracy: 0.3200
# Epoch 2/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.9777 - accuracy: 0.3261 - val_loss: 1.9413 - val_accuracy: 0.3270
# Epoch 3/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8925 - accuracy: 0.3491 - val_loss: 1.8767 - val_accuracy: 0.3578
# Epoch 4/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8570 - accuracy: 0.3679 - val_loss: 1.8353 - val_accuracy: 0.3782
# Epoch 5/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8177 - accuracy: 0.3834 - val_loss: 1.8630 - val_accuracy: 0.3656
# Epoch 6/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7998 - accuracy: 0.3854 - val_loss: 1.8185 - val_accuracy: 0.3690
# 18/18 [==============================] - 0s 13ms/step - loss: 1.7991 - accuracy: 0.3893
#
#
#
#
#
# current params:
# 	 2 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_75"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_260 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_261 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_262 (Dense)            (None, 10)                3850
# =================================================================
# Total params: 2,714,522
# Trainable params: 2,714,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.5921 - accuracy: 0.2536 - val_loss: 2.0295 - val_accuracy: 0.3314
# Epoch 2/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.9570 - accuracy: 0.3385 - val_loss: 1.9311 - val_accuracy: 0.3274
# Epoch 3/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8893 - accuracy: 0.3526 - val_loss: 1.9336 - val_accuracy: 0.3272
# 18/18 [==============================] - 0s 14ms/step - loss: 1.9228 - accuracy: 0.3410
#
#
#
#
#
# current params:
# 	 3 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_76"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_263 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_264 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_265 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_266 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 2.4285 - accuracy: 0.2004 - val_loss: 2.0203 - val_accuracy: 0.2704
# Epoch 2/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.9686 - accuracy: 0.2962 - val_loss: 1.9422 - val_accuracy: 0.3124
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9255 - accuracy: 0.3160 - val_loss: 1.9114 - val_accuracy: 0.3300
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8760 - accuracy: 0.3438 - val_loss: 1.8859 - val_accuracy: 0.3422
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8494 - accuracy: 0.3534 - val_loss: 1.8435 - val_accuracy: 0.3528
# Epoch 6/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8502 - accuracy: 0.3530 - val_loss: 1.8782 - val_accuracy: 0.3338
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8269 - accuracy: 0.3619 - val_loss: 1.8117 - val_accuracy: 0.3624
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7931 - accuracy: 0.3756 - val_loss: 1.8002 - val_accuracy: 0.3652
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7935 - accuracy: 0.3779 - val_loss: 1.8210 - val_accuracy: 0.3652
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7853 - accuracy: 0.3838 - val_loss: 1.8323 - val_accuracy: 0.3560
# 18/18 [==============================] - 0s 14ms/step - loss: 1.7984 - accuracy: 0.3730
#
#
#
#
#
# current params:
# 	 3 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_77"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_267 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_268 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_269 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_270 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 33ms/step - loss: 2.4615 - accuracy: 0.1848 - val_loss: 2.0786 - val_accuracy: 0.2234
# Epoch 2/200
# 71/71 [==============================] - 2s 28ms/step - loss: 1.9809 - accuracy: 0.2919 - val_loss: 1.9764 - val_accuracy: 0.2916
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9278 - accuracy: 0.3152 - val_loss: 1.9139 - val_accuracy: 0.3214
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8863 - accuracy: 0.3372 - val_loss: 1.8599 - val_accuracy: 0.3388
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8501 - accuracy: 0.3534 - val_loss: 1.8887 - val_accuracy: 0.3322
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8332 - accuracy: 0.3593 - val_loss: 1.8168 - val_accuracy: 0.3642
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8144 - accuracy: 0.3699 - val_loss: 1.8024 - val_accuracy: 0.3690
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7851 - accuracy: 0.3783 - val_loss: 1.8481 - val_accuracy: 0.3474
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7790 - accuracy: 0.3833 - val_loss: 1.7901 - val_accuracy: 0.3826
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7608 - accuracy: 0.3918 - val_loss: 1.8007 - val_accuracy: 0.3778
# Epoch 11/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7586 - accuracy: 0.3914 - val_loss: 1.8627 - val_accuracy: 0.3520
# 18/18 [==============================] - 0s 12ms/step - loss: 1.8684 - accuracy: 0.3491
#
#
#
#
#
# current params:
# 	 3 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_78"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_271 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_272 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_273 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_274 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 32ms/step - loss: 2.4007 - accuracy: 0.2118 - val_loss: 1.9938 - val_accuracy: 0.2868
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9761 - accuracy: 0.2984 - val_loss: 1.9608 - val_accuracy: 0.3038
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9099 - accuracy: 0.3276 - val_loss: 1.9337 - val_accuracy: 0.3008
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8913 - accuracy: 0.3396 - val_loss: 1.8558 - val_accuracy: 0.3458
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8407 - accuracy: 0.3601 - val_loss: 1.9097 - val_accuracy: 0.3348
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8348 - accuracy: 0.3607 - val_loss: 1.8285 - val_accuracy: 0.3578
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8070 - accuracy: 0.3752 - val_loss: 1.8915 - val_accuracy: 0.3406
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8058 - accuracy: 0.3752 - val_loss: 1.7892 - val_accuracy: 0.3782
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7958 - accuracy: 0.3805 - val_loss: 1.7986 - val_accuracy: 0.3790
# Epoch 10/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.7710 - accuracy: 0.3905 - val_loss: 1.7834 - val_accuracy: 0.3878
# Epoch 11/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7454 - accuracy: 0.3994 - val_loss: 1.7978 - val_accuracy: 0.3794
# Epoch 12/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7476 - accuracy: 0.3993 - val_loss: 1.7874 - val_accuracy: 0.3798
# 18/18 [==============================] - 0s 14ms/step - loss: 1.7750 - accuracy: 0.3810
#
#
#
#
#
# current params:
# 	 3 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_79"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_275 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_276 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_277 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_278 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 32ms/step - loss: 2.4534 - accuracy: 0.1891 - val_loss: 2.0642 - val_accuracy: 0.2576
# Epoch 2/200
# 71/71 [==============================] - 2s 31ms/step - loss: 1.9727 - accuracy: 0.2974 - val_loss: 2.0477 - val_accuracy: 0.2798
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9250 - accuracy: 0.3246 - val_loss: 1.9122 - val_accuracy: 0.3140
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8859 - accuracy: 0.3353 - val_loss: 1.8939 - val_accuracy: 0.3332
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8608 - accuracy: 0.3472 - val_loss: 1.9063 - val_accuracy: 0.3444
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8365 - accuracy: 0.3574 - val_loss: 1.8439 - val_accuracy: 0.3516
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8110 - accuracy: 0.3641 - val_loss: 1.8495 - val_accuracy: 0.3564
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7994 - accuracy: 0.3723 - val_loss: 1.8001 - val_accuracy: 0.3652
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7996 - accuracy: 0.3728 - val_loss: 1.7980 - val_accuracy: 0.3776
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7747 - accuracy: 0.3872 - val_loss: 1.7579 - val_accuracy: 0.3840
# Epoch 11/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7594 - accuracy: 0.3942 - val_loss: 1.9045 - val_accuracy: 0.3386
# Epoch 12/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7495 - accuracy: 0.3975 - val_loss: 1.7655 - val_accuracy: 0.3804
# 18/18 [==============================] - 0s 14ms/step - loss: 1.7376 - accuracy: 0.4043
#
#
#
#
#
# current params:
# 	 3 384 128 sigmoid SparseCategoricalCrossentropy
# Model: "sequential_80"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_279 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_280 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_281 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_282 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 2.4199 - accuracy: 0.2088 - val_loss: 2.0166 - val_accuracy: 0.2772
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9673 - accuracy: 0.3014 - val_loss: 1.9914 - val_accuracy: 0.2844
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9257 - accuracy: 0.3214 - val_loss: 1.9542 - val_accuracy: 0.3062
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8948 - accuracy: 0.3322 - val_loss: 1.8848 - val_accuracy: 0.3358
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8511 - accuracy: 0.3532 - val_loss: 1.8770 - val_accuracy: 0.3396
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8241 - accuracy: 0.3659 - val_loss: 1.8748 - val_accuracy: 0.3384
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8373 - accuracy: 0.3624 - val_loss: 1.8538 - val_accuracy: 0.3440
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8005 - accuracy: 0.3778 - val_loss: 1.8912 - val_accuracy: 0.3460
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7788 - accuracy: 0.3849 - val_loss: 1.8373 - val_accuracy: 0.3508
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7755 - accuracy: 0.3878 - val_loss: 1.7945 - val_accuracy: 0.3734
# Epoch 11/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7560 - accuracy: 0.3924 - val_loss: 1.7641 - val_accuracy: 0.3880
# Epoch 12/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7331 - accuracy: 0.4076 - val_loss: 1.7548 - val_accuracy: 0.3992
# Epoch 13/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7348 - accuracy: 0.4056 - val_loss: 1.8194 - val_accuracy: 0.3674
# Epoch 14/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7260 - accuracy: 0.4120 - val_loss: 1.7448 - val_accuracy: 0.4064
# Epoch 15/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7152 - accuracy: 0.4151 - val_loss: 1.7998 - val_accuracy: 0.3812
# Epoch 16/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6898 - accuracy: 0.4260 - val_loss: 1.7720 - val_accuracy: 0.4066
# Epoch 17/200
# ...
# Total params: 2,714,522
# Trainable params: 2,714,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 30ms/step - loss: 3.4415 - accuracy: 0.1758 - val_loss: 2.8411 - val_accuracy: 0.2698
# Epoch 2/200
# 71/71 [==============================] - 2s 29ms/step - loss: 2.5290 - accuracy: 0.2937 - val_loss: 2.3651 - val_accuracy: 0.2908
# Epoch 3/200
# 71/71 [==============================] - 2s 29ms/step - loss: 2.1558 - accuracy: 0.3405 - val_loss: 2.1108 - val_accuracy: 0.3176
# Epoch 4/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.9604 - accuracy: 0.3681 - val_loss: 1.9204 - val_accuracy: 0.3736
# Epoch 5/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.8398 - accuracy: 0.3896 - val_loss: 1.8346 - val_accuracy: 0.3750
# Epoch 6/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7743 - accuracy: 0.4066 - val_loss: 1.8174 - val_accuracy: 0.3770
# Epoch 7/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.7232 - accuracy: 0.4216 - val_loss: 1.7672 - val_accuracy: 0.3884
# Epoch 8/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.6882 - accuracy: 0.4310 - val_loss: 1.7100 - val_accuracy: 0.4200
# Epoch 9/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.6630 - accuracy: 0.4385 - val_loss: 1.7151 - val_accuracy: 0.4212
# Epoch 10/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.6351 - accuracy: 0.4466 - val_loss: 1.7024 - val_accuracy: 0.4104
# Epoch 11/200
# 71/71 [==============================] - 2s 29ms/step - loss: 1.6307 - accuracy: 0.4455 - val_loss: 1.7968 - val_accuracy: 0.3820
# 18/18 [==============================] - 0s 13ms/step - loss: 1.7900 - accuracy: 0.3920
#
#
#
#
#
# current params:
# 	 3 384 128 tanh SparseCategoricalCrossentropy
# Model: "sequential_116"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_403 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_404 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_405 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_406 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 3.2431 - accuracy: 0.2046 - val_loss: 2.6865 - val_accuracy: 0.2692
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.4161 - accuracy: 0.3077 - val_loss: 2.2159 - val_accuracy: 0.3180
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.0895 - accuracy: 0.3395 - val_loss: 1.9848 - val_accuracy: 0.3554
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9148 - accuracy: 0.3668 - val_loss: 1.9832 - val_accuracy: 0.3332
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8502 - accuracy: 0.3772 - val_loss: 1.8382 - val_accuracy: 0.3724
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7613 - accuracy: 0.4039 - val_loss: 1.7665 - val_accuracy: 0.3938
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7418 - accuracy: 0.4054 - val_loss: 1.8824 - val_accuracy: 0.3642
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6988 - accuracy: 0.4242 - val_loss: 1.7247 - val_accuracy: 0.4096
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6840 - accuracy: 0.4286 - val_loss: 1.7008 - val_accuracy: 0.4220
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6540 - accuracy: 0.4398 - val_loss: 1.8071 - val_accuracy: 0.3762
# Epoch 11/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6422 - accuracy: 0.4439 - val_loss: 1.6443 - val_accuracy: 0.4370
# Epoch 12/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6278 - accuracy: 0.4486 - val_loss: 1.6499 - val_accuracy: 0.4420
# Epoch 13/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.5863 - accuracy: 0.4636 - val_loss: 1.9927 - val_accuracy: 0.3646
# Epoch 14/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6051 - accuracy: 0.4576 - val_loss: 1.6854 - val_accuracy: 0.4332
# 18/18 [==============================] - 0s 13ms/step - loss: 1.6510 - accuracy: 0.4413
#
#
#
#
#
# current params:
# 	 3 384 128 tanh SparseCategoricalCrossentropy
# Model: "sequential_117"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_407 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_408 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_409 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_410 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 3.3171 - accuracy: 0.1583 - val_loss: 2.7009 - val_accuracy: 0.2334
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.4049 - accuracy: 0.2872 - val_loss: 2.2535 - val_accuracy: 0.2942
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.0605 - accuracy: 0.3320 - val_loss: 1.9675 - val_accuracy: 0.3340
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9025 - accuracy: 0.3571 - val_loss: 1.8793 - val_accuracy: 0.3440
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8174 - accuracy: 0.3766 - val_loss: 1.8337 - val_accuracy: 0.3632
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7653 - accuracy: 0.3972 - val_loss: 1.7875 - val_accuracy: 0.3762
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7330 - accuracy: 0.4062 - val_loss: 1.7760 - val_accuracy: 0.3848
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6959 - accuracy: 0.4178 - val_loss: 1.7350 - val_accuracy: 0.4004
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6784 - accuracy: 0.4279 - val_loss: 1.8345 - val_accuracy: 0.3782
# Epoch 10/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6701 - accuracy: 0.4299 - val_loss: 1.8107 - val_accuracy: 0.3770
# 18/18 [==============================] - 0s 15ms/step - loss: 1.8136 - accuracy: 0.3771
#
#
#
#
#
# current params:
# 	 3 384 128 tanh SparseCategoricalCrossentropy
# Model: "sequential_118"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_411 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_412 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_413 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_414 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 32ms/step - loss: 3.2320 - accuracy: 0.1939 - val_loss: 2.6637 - val_accuracy: 0.2750
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.3794 - accuracy: 0.3122 - val_loss: 2.1554 - val_accuracy: 0.3324
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.0374 - accuracy: 0.3504 - val_loss: 2.0081 - val_accuracy: 0.3324
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8770 - accuracy: 0.3767 - val_loss: 1.9331 - val_accuracy: 0.3602
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8037 - accuracy: 0.3911 - val_loss: 1.9061 - val_accuracy: 0.3476
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7633 - accuracy: 0.4028 - val_loss: 1.7791 - val_accuracy: 0.3978
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7278 - accuracy: 0.4123 - val_loss: 1.7476 - val_accuracy: 0.3904
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7013 - accuracy: 0.4199 - val_loss: 1.7959 - val_accuracy: 0.3768
# 18/18 [==============================] - 0s 14ms/step - loss: 1.7948 - accuracy: 0.3798
#
#
#
#
#
# current params:
# 	 3 384 128 tanh SparseCategoricalCrossentropy
# Model: "sequential_119"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_415 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_416 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_417 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_418 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 3.4257 - accuracy: 0.1628 - val_loss: 2.8757 - val_accuracy: 0.2392
# Epoch 2/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.5577 - accuracy: 0.2948 - val_loss: 2.3164 - val_accuracy: 0.3056
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.1640 - accuracy: 0.3446 - val_loss: 2.0574 - val_accuracy: 0.3542
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9475 - accuracy: 0.3764 - val_loss: 1.9232 - val_accuracy: 0.3600
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8670 - accuracy: 0.3826 - val_loss: 1.8506 - val_accuracy: 0.3834
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7608 - accuracy: 0.4094 - val_loss: 1.9128 - val_accuracy: 0.3516
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7518 - accuracy: 0.4059 - val_loss: 1.7988 - val_accuracy: 0.3748
# 18/18 [==============================] - 0s 14ms/step - loss: 1.7710 - accuracy: 0.3901
# current params:
# 	 3 384 128 tanh SparseCategoricalCrossentropy
# Model: "sequential_120"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_419 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_420 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_421 (Dense)            (None, 256)               98560
# _________________________________________________________________
# dense_422 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 2,811,802
# Trainable params: 2,811,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 71/71 [==============================] - 2s 31ms/step - loss: 3.3247 - accuracy: 0.1647 - val_loss: 2.8525 - val_accuracy: 0.2148
# Epoch 2/200
# 71/71 [==============================] - 2s 31ms/step - loss: 2.4806 - accuracy: 0.2759 - val_loss: 2.3214 - val_accuracy: 0.2758
# Epoch 3/200
# 71/71 [==============================] - 2s 30ms/step - loss: 2.0979 - accuracy: 0.3318 - val_loss: 2.2006 - val_accuracy: 0.2742
# Epoch 4/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.9255 - accuracy: 0.3577 - val_loss: 1.8680 - val_accuracy: 0.3716
# Epoch 5/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.8125 - accuracy: 0.3882 - val_loss: 1.8407 - val_accuracy: 0.3628
# Epoch 6/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7738 - accuracy: 0.3939 - val_loss: 1.7772 - val_accuracy: 0.3830
# Epoch 7/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.7495 - accuracy: 0.4008 - val_loss: 1.7257 - val_accuracy: 0.4124
# Epoch 8/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6988 - accuracy: 0.4205 - val_loss: 1.7220 - val_accuracy: 0.4080
# Epoch 9/200
# 71/71 [==============================] - 2s 30ms/step - loss: 1.6870 - accuracy: 0.4244 - val_loss: 1.8188 - val_accuracy: 0.3796
# 18/18 [==============================] - 0s 15ms/step - loss: 1.8035 - accuracy: 0.3779
#
#
#
#
#
# current params:
# 	 2 384 128 relu SparseCategoricalCrossentropy
# Model: "sequential_121"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_423 (Dense)            (None, 784)               2409232
# _________________________________________________________________
# dense_424 (Dense)            (None, 384)               301440
# _________________________________________________________________
# dense_425 (Dense)            (None, 10)                3850
# =================================================================
# Total params: 2,714,522
# Trainable params: 2,714,522
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 88/88 [==============================] - 3s 30ms/step - loss: 3.1034 - accuracy: 0.2539 - val_loss: 2.5774 - val_accuracy: 0.3392
# Epoch 2/200
# 88/88 [==============================] - 3s 29ms/step - loss: 2.3869 - accuracy: 0.3574 - val_loss: 2.2420 - val_accuracy: 0.3724
# Epoch 3/200
# 88/88 [==============================] - 3s 29ms/step - loss: 2.1031 - accuracy: 0.3914 - val_loss: 2.0080 - val_accuracy: 0.3974
# Epoch 4/200
# 88/88 [==============================] - 3s 29ms/step - loss: 1.9296 - accuracy: 0.4137 - val_loss: 1.8833 - val_accuracy: 0.4038
# Epoch 5/200
# 88/88 [==============================] - 3s 29ms/step - loss: 1.8084 - accuracy: 0.4322 - val_loss: 1.7934 - val_accuracy: 0.4216
# Epoch 6/200
# 88/88 [==============================] - 3s 29ms/step - loss: 1.7134 - accuracy: 0.4489 - val_loss: 1.7465 - val_accuracy: 0.4186
# Epoch 7/200
# 88/88 [==============================] - 3s 29ms/step - loss: 1.6542 - accuracy: 0.4600 - val_loss: 1.6681 - val_accuracy: 0.4442
# Epoch 8/200
# 88/88 [==============================] - 3s 29ms/step - loss: 1.6022 - accuracy: 0.4713 - val_loss: 1.6974 - val_accuracy: 0.4320
# Epoch 9/200
# 88/88 [==============================] - 3s 29ms/step - loss: 1.5898 - accuracy: 0.4698 - val_loss: 1.6581 - val_accuracy: 0.4406
# Finished model training in 1717s

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.4571777701377869
# {'activation_func': 'relu', 'batch_size': 512, 'epochs': 200, 'first_layer_nodes': 384, 'last_layer_nodes': 128, 'loss_func': 'SparseCategoricalCrossentropy', 'n_layers': 2}

# %%
loss, accuracy = grid.best_estimator_.evaluate(x_test_reshaped, y_test)
print('test set accuracy: ', accuracy * 100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6748/2795577705.py in <module>
# ----> 1 loss, accuracy = grid.best_estimator_.evaluate(x_test_reshaped, y_test)
#       2 print('test set accuracy: ', accuracy * 100)
#
# AttributeError: 'KerasClassifier' object has no attribute 'evaluate'

# %%
from sklearn_evaluation import plot as skplot
skplot.grid_search(grid.cv_results_, change='activation_func', kind='bar')
plt.legend(bbox_to_anchor=(1.5, -.3))

# %%
from sklearn_evaluation import plot as skplot
skplot.grid_search(grid.cv_results_, change='first_layer_nodes', kind='bar')
plt.legend(bbox_to_anchor=(1.5, -.3))

# %% [markdown]
# ## Plotting Performance Metrics
#
# We use Matplotlib to create 2 plots--displaying the training and validation loss (resp. accuracy) for each (training) epoch side by side.

# %%
pred1= grid.best_estimator_.predict(x_test_reshaped)
pred1=np.argmax(pred1, axis=1)
# Out:
# 20/20 [==============================] - 0s 9ms/step
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6748/2597736405.py in <module>
#       1 pred1= grid.best_estimator_.predict(x_test_reshaped)
# ----> 2 pred1=np.argmax(pred1, axis=1)
#
# <__array_function__ internals> in argmax(*args, **kwargs)
#
# ~\miniconda3\envs\tfgpu\lib\site-packages\numpy\core\fromnumeric.py in argmax(a, axis, out)
#    1184
#    1185     """
# -> 1186     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1187
#    1188
#
# ~\miniconda3\envs\tfgpu\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
print_validation_report(y_test, pred1)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.42      0.68      0.52      1000
#            1       0.49      0.70      0.58      1000
#            2       0.37      0.25      0.30      1000
#            3       0.35      0.34      0.35      1000
#            4       0.48      0.31      0.37      1000
#            5       0.41      0.30      0.35      1000
#            6       0.40      0.70      0.51      1000
#            7       0.63      0.40      0.49      1000
#            8       0.65      0.52      0.57      1000
#            9       0.59      0.45      0.51      1000
#
#     accuracy                           0.46     10000
#    macro avg       0.48      0.46      0.45     10000
# weighted avg       0.48      0.46      0.45     10000
#
# Accuracy Score: 0.4645
# Root Mean Square Error: 3.260659442505457

# %%
plot_confusion_matrix(y_test,pred1)
